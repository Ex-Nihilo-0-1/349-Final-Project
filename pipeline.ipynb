# %%
from data_processing import *
import datetime 
import pandas as pd
pd.set_option('display.max_rows', 100) 
pd.set_option('display.max_columns', 100)

# %%
data = read_data('countypres_2000-2020.csv')
df = pd.DataFrame(data)
df['state'] = df['state'].apply(lambda x: "District of Columbia" if x == "DISTRICT OF COLUMBIA" else x.title())
df['county_name'] = df['county_name'].apply(lambda x: "District of Columbia" if x == "DISTRICT OF COLUMBIA" else x.title())
df.set_index(['state', 'county_name', 'year'], inplace=True)
additional_data = []
for loc_idx in list(set(df.index)):
    iloc_idx = np.array(df.loc[loc_idx]['candidatevotes'].apply(int)).argmax()
    dict = {}
    name = df.loc[loc_idx].iloc[iloc_idx].name
    dict['State'] = name[0]
    dict['Year'] = name[2]
    dict['County'] = name[1]
    dict['Party'] = 'D' if df.loc[loc_idx].iloc[iloc_idx].to_dict()['party'] == 'DEMOCRAT' else 'R'
    additional_data += [dict]

# %%
data = read_data('by_county.csv')
data = data + additional_data
data = sorted(data, key=lambda d: d['State'])
data = sorted(data, key=lambda d: int(d['Year']))

filename_t1 = datetime.datetime.now().__str__()
with open(filename_t1, 'w') as csvfile:
    writer = csv.DictWriter(csvfile, fieldnames=['State', 'Year', 'County', 'Party'])
    writer.writeheader()
    writer.writerows(data)

# %%
# for _ in data:
   
#     _['State'] = _['state']
#     del _['state']
#     _['State'] = _['State'].capitalize()

#     _['Year'] = _['year']
#     del _['year']

#     _['Party'] = _['party']
#     del _['party']
#     _['Party'] = 'D' if _['Party'] =='DEMOCRAT' else 'R'

#     _['County'] = _['county_name']
#     del _['county_name']
#     _['County'] = _['County'].capitalize()
    

#     del _['candidate']
#     del _['candidatevotes']
#     del _['county_fips']
#     del _['version']
#     del _['mode']
#     del _['totalvotes']
#     del _['office']
#     del _['state_po']

# %%
'LA', 'AK', 'WA'
# Out:
# ('LA', 'AK', 'WA')

# %%
WA_result = []
for i in range(10):
    try:
        year = 2000 - 4*i
        http = "https://en.wikipedia.org/wiki/" + str(year) + "_United_States_presidential_election_in_Washington_(state)"
        f = r.get(http)
        html_content = f.content
        soup = BeautifulSoup(html_content, 'html.parser')
        tables = [table for table in soup.find_all("table")]
        # states_list = []
        # for _ in table.find_all("tr")[2:]:
        #     states_list += [_.find("td").text]
        # return states_list[:-2]
        for _ in tables[11].find_all("tr")[2:]:
            try:
                dict = {}
                county = _.find("td").text.strip('\n')
                party = "R" if _.find("td")['style'].strip('background-color:') == '#FFB6B6' else "D"
                
                dict['State'] = 'Washington'
                dict['Year'] = year
                dict['County'] = county
                dict['Party'] = party
                WA_result += [dict]
            except Exception as e:
                print(e)
                pass
    except Exception as e:
        print(e)
        pass
# Out:
# 'NoneType' object has no attribute 'text'
# 'NoneType' object has no attribute 'text'
# 'NoneType' object has no attribute 'text'
# 'NoneType' object has no attribute 'text'
# 'NoneType' object has no attribute 'text'
# 'NoneType' object has no attribute 'text'
# 'NoneType' object has no attribute 'text'
# 'NoneType' object has no attribute 'text'
# 'NoneType' object has no attribute 'text'

# %%
WA_result
# Out:
# [{'State': 'Washington', 'Year': 2000, 'County': 'Adams', 'Party': 'R'},
#  {'State': 'Washington', 'Year': 2000, 'County': 'Asotin', 'Party': 'R'},
#  {'State': 'Washington', 'Year': 2000, 'County': 'Benton', 'Party': 'R'},
#  {'State': 'Washington', 'Year': 2000, 'County': 'Chelan', 'Party': 'R'},
#  {'State': 'Washington', 'Year': 2000, 'County': 'Clallam', 'Party': 'R'},
#  {'State': 'Washington', 'Year': 2000, 'County': 'Clark', 'Party': 'R'},
#  {'State': 'Washington', 'Year': 2000, 'County': 'Columbia', 'Party': 'R'},
#  {'State': 'Washington', 'Year': 2000, 'County': 'Cowlitz', 'Party': 'D'},
#  {'State': 'Washington', 'Year': 2000, 'County': 'Douglas', 'Party': 'R'},
#  {'State': 'Washington', 'Year': 2000, 'County': 'Ferry', 'Party': 'R'},
#  {'State': 'Washington', 'Year': 2000, 'County': 'Franklin', 'Party': 'R'},
#  {'State': 'Washington', 'Year': 2000, 'County': 'Garfield', 'Party': 'R'},
#  {'State': 'Washington', 'Year': 2000, 'County': 'Grant', 'Party': 'R'},
#  {'State': 'Washington', 'Year': 2000, 'County': 'Grays Harbor', 'Party': 'D'},
#  {'State': 'Washington', 'Year': 2000, 'County': 'Island', 'Party': 'R'},
#  {'State': 'Washington', 'Year': 2000, 'County': 'Jefferson', 'Party': 'D'},
#  {'State': 'Washington', 'Year': 2000, 'County': 'King', 'Party': 'D'},
#  {'State': 'Washington', 'Year': 2000, 'County': 'Kitsap', 'Party': 'D'},
#  {'State': 'Washington', 'Year': 2000, 'County': 'Kittitas', 'Party': 'R'},
#  {'State': 'Washington', 'Year': 2000, 'County': 'Klickitat', 'Party': 'R'},
#  {'State': 'Washington', 'Year': 2000, 'County': 'Lewis', 'Party': 'R'},
#  {'State': 'Washington', 'Year': 2000, 'County': 'Lincoln', 'Party': 'R'},
#  {'State': 'Washington', 'Year': 2000, 'County': 'Mason', 'Party': 'D'},
#  {'State': 'Washington', 'Year': 2000, 'County': 'Okanogan', 'Party': 'R'},
#  {'State': 'Washington', 'Year': 2000, 'County': 'Pacific', 'Party': 'D'},
#  {'State': 'Washington', 'Year': 2000, 'County': 'Pend Oreille', 'Party': 'R'},
#  {'State': 'Washington', 'Year': 2000, 'County': 'Pierce', 'Party': 'D'},
#  {'State': 'Washington', 'Year': 2000, 'County': 'San Juan', 'Party': 'D'},
#  {'State': 'Washington', 'Year': 2000, 'County': 'Skagit', 'Party': 'R'},
#  {'State': 'Washington', 'Year': 2000, 'County': 'Skamania', 'Party': 'R'},
#  {'State': 'Washington', 'Year': 2000, 'County': 'Snohomish', 'Party': 'D'},
#  {'State': 'Washington', 'Year': 2000, 'County': 'Spokane', 'Party': 'R'},
#  {'State': 'Washington', 'Year': 2000, 'County': 'Stevens', 'Party': 'R'},
#  {'State': 'Washington', 'Year': 2000, 'County': 'Thurston', 'Party': 'D'},
#  {'State': 'Washington', 'Year': 2000, 'County': 'Wahkiakum', 'Party': 'R'},
#  {'State': 'Washington', 'Year': 2000, 'County': 'Walla Walla', 'Party': 'R'},
#  {'State': 'Washington', 'Year': 2000, 'County': 'Whatcom', 'Party': 'R'},
#  {'State': 'Washington', 'Year': 2000, 'County': 'Whitman', 'Party': 'R'},
#  {'State': 'Washington', 'Year': 2000, 'County': 'Yakima', 'Party': 'R'},
#  {'State': 'Washington', 'Year': 1996, 'County': 'Adams', 'Party': 'R'},
#  {'State': 'Washington', 'Year': 1996, 'County': 'Asotin', 'Party': 'D'},
#  {'State': 'Washington', 'Year': 1996, 'County': 'Benton', 'Party': 'R'},
#  {'State': 'Washington', 'Year': 1996, 'County': 'Chelan', 'Party': 'R'},
#  {'State': 'Washington', 'Year': 1996, 'County': 'Clallam', 'Party': 'D'},
#  {'State': 'Washington', 'Year': 1996, 'County': 'Clark', 'Party': 'D'},
#  {'State': 'Washington', 'Year': 1996, 'County': 'Columbia', 'Party': 'R'},
#  {'State': 'Washington', 'Year': 1996, 'County': 'Cowlitz', 'Party': 'D'},
#  {'State': 'Washington', 'Year': 1996, 'County': 'Douglas', 'Party': 'R'},
#  {'State': 'Washington', 'Year': 1996, 'County': 'Ferry', 'Party': 'D'},
#  {'State': 'Washington', 'Year': 1996, 'County': 'Franklin', 'Party': 'R'},
#  {'State': 'Washington', 'Year': 1996, 'County': 'Garfield', 'Party': 'R'},
#  {'State': 'Washington', 'Year': 1996, 'County': 'Grant', 'Party': 'R'},
#  {'State': 'Washington', 'Year': 1996, 'County': 'Grays Harbor', 'Party': 'D'},
#  {'State': 'Washington', 'Year': 1996, 'County': 'Island', 'Party': 'R'},
#  {'State': 'Washington', 'Year': 1996, 'County': 'Jefferson', 'Party': 'D'},
#  {'State': 'Washington', 'Year': 1996, 'County': 'King', 'Party': 'D'},
#  {'State': 'Washington', 'Year': 1996, 'County': 'Kitsap', 'Party': 'D'},
#  {'State': 'Washington', 'Year': 1996, 'County': 'Kittitas', 'Party': 'D'},
#  {'State': 'Washington', 'Year': 1996, 'County': 'Klickitat', 'Party': 'D'},
#  {'State': 'Washington', 'Year': 1996, 'County': 'Lewis', 'Party': 'R'},
#  {'State': 'Washington', 'Year': 1996, 'County': 'Lincoln', 'Party': 'R'},
#  {'State': 'Washington', 'Year': 1996, 'County': 'Mason', 'Party': 'D'},
#  {'State': 'Washington', 'Year': 1996, 'County': 'Okanogan', 'Party': 'R'},
#  {'State': 'Washington', 'Year': 1996, 'County': 'Pacific', 'Party': 'D'},
#  {'State': 'Washington', 'Year': 1996, 'County': 'Pend Oreille', 'Party': 'D'},
#  {'State': 'Washington', 'Year': 1996, 'County': 'Pierce', 'Party': 'D'},
#  {'State': 'Washington', 'Year': 1996, 'County': 'San Juan', 'Party': 'D'},
#  {'State': 'Washington', 'Year': 1996, 'County': 'Skagit', 'Party': 'D'},
#  {'State': 'Washington', 'Year': 1996, 'County': 'Skamania', 'Party': 'D'},
#  {'State': 'Washington', 'Year': 1996, 'County': 'Snohomish', 'Party': 'D'},
#  {'State': 'Washington', 'Year': 1996, 'County': 'Spokane', 'Party': 'D'},
#  {'State': 'Washington', 'Year': 1996, 'County': 'Stevens', 'Party': 'R'},
#  {'State': 'Washington', 'Year': 1996, 'County': 'Thurston', 'Party': 'D'},
#  {'State': 'Washington', 'Year': 1996, 'County': 'Wahkiakum', 'Party': 'D'},
#  {'State': 'Washington', 'Year': 1996, 'County': 'Walla Walla', 'Party': 'R'},
#  {'State': 'Washington', 'Year': 1996, 'County': 'Whatcom', 'Party': 'D'},
#  {'State': 'Washington', 'Year': 1996, 'County': 'Whitman', 'Party': 'D'},
#  {'State': 'Washington', 'Year': 1996, 'County': 'Yakima', 'Party': 'R'},
#  {'State': 'Washington', 'Year': 1992, 'County': 'Adams', 'Party': 'R'},
#  {'State': 'Washington', 'Year': 1992, 'County': 'Asotin', 'Party': 'D'},
#  {'State': 'Washington', 'Year': 1992, 'County': 'Benton', 'Party': 'R'},
#  {'State': 'Washington', 'Year': 1992, 'County': 'Chelan', 'Party': 'R'},
#  {'State': 'Washington', 'Year': 1992, 'County': 'Clallam', 'Party': 'D'},
#  {'State': 'Washington', 'Year': 1992, 'County': 'Clark', 'Party': 'D'},
#  {'State': 'Washington', 'Year': 1992, 'County': 'Columbia', 'Party': 'R'},
#  {'State': 'Washington', 'Year': 1992, 'County': 'Cowlitz', 'Party': 'D'},
#  {'State': 'Washington', 'Year': 1992, 'County': 'Douglas', 'Party': 'R'},
#  {'State': 'Washington', 'Year': 1992, 'County': 'Ferry', 'Party': 'D'},
#  {'State': 'Washington', 'Year': 1992, 'County': 'Franklin', 'Party': 'R'},
#  {'State': 'Washington', 'Year': 1992, 'County': 'Garfield', 'Party': 'R'},
#  {'State': 'Washington', 'Year': 1992, 'County': 'Grant', 'Party': 'R'},
#  {'State': 'Washington', 'Year': 1992, 'County': 'Grays Harbor', 'Party': 'D'},
#  {'State': 'Washington', 'Year': 1992, 'County': 'Island', 'Party': 'D'},
#  {'State': 'Washington', 'Year': 1992, 'County': 'Jefferson', 'Party': 'D'},
#  {'State': 'Washington', 'Year': 1992, 'County': 'King', 'Party': 'D'},
#  {'State': 'Washington', 'Year': 1992, 'County': 'Kitsap', 'Party': 'D'},
#  {'State': 'Washington', 'Year': 1992, 'County': 'Kittitas', 'Party': 'D'},
#  {'State': 'Washington', 'Year': 1992, 'County': 'Klickitat', 'Party': 'D'},
#  {'State': 'Washington', 'Year': 1992, 'County': 'Lewis', 'Party': 'R'},
#  {'State': 'Washington', 'Year': 1992, 'County': 'Lincoln', 'Party': 'R'},
#  {'State': 'Washington', 'Year': 1992, 'County': 'Mason', 'Party': 'D'},
#  {'State': 'Washington', 'Year': 1992, 'County': 'Okanogan', 'Party': 'D'},
#  {'State': 'Washington', 'Year': 1992, 'County': 'Pacific', 'Party': 'D'},
#  {'State': 'Washington', 'Year': 1992, 'County': 'Pend Oreille', 'Party': 'D'},
#  {'State': 'Washington', 'Year': 1992, 'County': 'Pierce', 'Party': 'D'},
#  {'State': 'Washington', 'Year': 1992, 'County': 'San Juan', 'Party': 'D'},
#  {'State': 'Washington', 'Year': 1992, 'County': 'Skagit', 'Party': 'D'},
#  {'State': 'Washington', 'Year': 1992, 'County': 'Skamania', 'Party': 'D'},
#  {'State': 'Washington', 'Year': 1992, 'County': 'Snohomish', 'Party': 'D'},
#  {'State': 'Washington', 'Year': 1992, 'County': 'Spokane', 'Party': 'D'},
#  {'State': 'Washington', 'Year': 1992, 'County': 'Stevens', 'Party': 'R'},
#  {'State': 'Washington', 'Year': 1992, 'County': 'Thurston', 'Party': 'D'},
#  {'State': 'Washington', 'Year': 1992, 'County': 'Wahkiakum', 'Party': 'D'},
#  {'State': 'Washington', 'Year': 1992, 'County': 'Walla Walla', 'Party': 'R'},
#  {'State': 'Washington', 'Year': 1992, 'County': 'Whatcom', 'Party': 'D'},
#  {'State': 'Washington', 'Year': 1992, 'County': 'Whitman', 'Party': 'D'},
#  {'State': 'Washington', 'Year': 1992, 'County': 'Yakima', 'Party': 'R'},
#  {'State': 'Washington', 'Year': 1988, 'County': 'Adams', 'Party': 'R'},
#  {'State': 'Washington', 'Year': 1988, 'County': 'Asotin', 'Party': 'D'},
#  {'State': 'Washington', 'Year': 1988, 'County': 'Benton', 'Party': 'R'},
#  {'State': 'Washington', 'Year': 1988, 'County': 'Chelan', 'Party': 'R'},
#  {'State': 'Washington', 'Year': 1988, 'County': 'Clallam', 'Party': 'R'},
#  {'State': 'Washington', 'Year': 1988, 'County': 'Clark', 'Party': 'D'},
#  {'State': 'Washington', 'Year': 1988, 'County': 'Columbia', 'Party': 'R'},
#  {'State': 'Washington', 'Year': 1988, 'County': 'Cowlitz', 'Party': 'D'},
#  {'State': 'Washington', 'Year': 1988, 'County': 'Douglas', 'Party': 'R'},
#  {'State': 'Washington', 'Year': 1988, 'County': 'Ferry', 'Party': 'D'},
#  {'State': 'Washington', 'Year': 1988, 'County': 'Franklin', 'Party': 'R'},
#  {'State': 'Washington', 'Year': 1988, 'County': 'Garfield', 'Party': 'R'},
#  {'State': 'Washington', 'Year': 1988, 'County': 'Grant', 'Party': 'R'},
#  {'State': 'Washington', 'Year': 1988, 'County': 'Grays Harbor', 'Party': 'D'},
#  {'State': 'Washington', 'Year': 1988, 'County': 'Island', 'Party': 'R'},
#  {'State': 'Washington', 'Year': 1988, 'County': 'Jefferson', 'Party': 'D'},
#  {'State': 'Washington', 'Year': 1988, 'County': 'King', 'Party': 'D'},
#  {'State': 'Washington', 'Year': 1988, 'County': 'Kitsap', 'Party': 'R'},
#  {'State': 'Washington', 'Year': 1988, 'County': 'Kittitas', 'Party': 'D'},
#  {'State': 'Washington', 'Year': 1988, 'County': 'Klickitat', 'Party': 'D'},
#  {'State': 'Washington', 'Year': 1988, 'County': 'Lewis', 'Party': 'R'},
#  {'State': 'Washington', 'Year': 1988, 'County': 'Lincoln', 'Party': 'R'},
#  {'State': 'Washington', 'Year': 1988, 'County': 'Mason', 'Party': 'D'},
#  {'State': 'Washington', 'Year': 1988, 'County': 'Okanogan', 'Party': 'R'},
#  {'State': 'Washington', 'Year': 1988, 'County': 'Pacific', 'Party': 'D'},
#  {'State': 'Washington', 'Year': 1988, 'County': 'Pend Oreille', 'Party': 'D'},
#  {'State': 'Washington', 'Year': 1988, 'County': 'Pierce', 'Party': 'D'},
#  {'State': 'Washington', 'Year': 1988, 'County': 'San Juan', 'Party': 'D'},
#  {'State': 'Washington', 'Year': 1988, 'County': 'Skagit', 'Party': 'R'},
#  {'State': 'Washington', 'Year': 1988, 'County': 'Skamania', 'Party': 'D'},
#  {'State': 'Washington', 'Year': 1988, 'County': 'Snohomish', 'Party': 'R'},
#  {'State': 'Washington', 'Year': 1988, 'County': 'Spokane', 'Party': 'R'},
#  {'State': 'Washington', 'Year': 1988, 'County': 'Stevens', 'Party': 'R'},
#  {'State': 'Washington', 'Year': 1988, 'County': 'Thurston', 'Party': 'D'},
#  {'State': 'Washington', 'Year': 1988, 'County': 'Wahkiakum', 'Party': 'D'},
#  {'State': 'Washington', 'Year': 1988, 'County': 'Walla Walla', 'Party': 'R'},
#  {'State': 'Washington', 'Year': 1988, 'County': 'Whatcom', 'Party': 'D'},
#  {'State': 'Washington', 'Year': 1988, 'County': 'Whitman', 'Party': 'R'},
#  {'State': 'Washington', 'Year': 1988, 'County': 'Yakima', 'Party': 'R'},
#  {'State': 'Washington', 'Year': 1984, 'County': 'Adams', 'Party': 'R'},
#  {'State': 'Washington', 'Year': 1984, 'County': 'Asotin', 'Party': 'R'},
#  {'State': 'Washington', 'Year': 1984, 'County': 'Benton', 'Party': 'R'},
#  {'State': 'Washington', 'Year': 1984, 'County': 'Chelan', 'Party': 'R'},
#  {'State': 'Washington', 'Year': 1984, 'County': 'Clallam', 'Party': 'R'},
#  {'State': 'Washington', 'Year': 1984, 'County': 'Clark', 'Party': 'R'},
#  {'State': 'Washington', 'Year': 1984, 'County': 'Columbia', 'Party': 'R'},
#  {'State': 'Washington', 'Year': 1984, 'County': 'Cowlitz', 'Party': 'D'},
#  {'State': 'Washington', 'Year': 1984, 'County': 'Douglas', 'Party': 'R'},
#  {'State': 'Washington', 'Year': 1984, 'County': 'Ferry', 'Party': 'R'},
#  {'State': 'Washington', 'Year': 1984, 'County': 'Franklin', 'Party': 'R'},
#  {'State': 'Washington', 'Year': 1984, 'County': 'Garfield', 'Party': 'R'},
#  {'State': 'Washington', 'Year': 1984, 'County': 'Grant', 'Party': 'R'},
#  {'State': 'Washington', 'Year': 1984, 'County': 'Grays Harbor', 'Party': 'D'},
#  {'State': 'Washington', 'Year': 1984, 'County': 'Island', 'Party': 'R'},
#  {'State': 'Washington', 'Year': 1984, 'County': 'Jefferson', 'Party': 'D'},
#  {'State': 'Washington', 'Year': 1984, 'County': 'King', 'Party': 'R'},
#  {'State': 'Washington', 'Year': 1984, 'County': 'Kitsap', 'Party': 'R'},
#  {'State': 'Washington', 'Year': 1984, 'County': 'Kittitas', 'Party': 'R'},
#  {'State': 'Washington', 'Year': 1984, 'County': 'Klickitat', 'Party': 'R'},
#  {'State': 'Washington', 'Year': 1984, 'County': 'Lewis', 'Party': 'R'},
#  {'State': 'Washington', 'Year': 1984, 'County': 'Lincoln', 'Party': 'R'},
#  {'State': 'Washington', 'Year': 1984, 'County': 'Mason', 'Party': 'R'},
#  {'State': 'Washington', 'Year': 1984, 'County': 'Okanogan', 'Party': 'R'},
#  {'State': 'Washington', 'Year': 1984, 'County': 'Pacific', 'Party': 'D'},
#  {'State': 'Washington', 'Year': 1984, 'County': 'Pend Oreille', 'Party': 'R'},
#  {'State': 'Washington', 'Year': 1984, 'County': 'Pierce', 'Party': 'R'},
#  {'State': 'Washington', 'Year': 1984, 'County': 'San Juan', 'Party': 'R'},
#  {'State': 'Washington', 'Year': 1984, 'County': 'Skagit', 'Party': 'R'},
#  {'State': 'Washington', 'Year': 1984, 'County': 'Skamania', 'Party': 'R'},
#  {'State': 'Washington', 'Year': 1984, 'County': 'Snohomish', 'Party': 'R'},
#  {'State': 'Washington', 'Year': 1984, 'County': 'Spokane', 'Party': 'R'},
#  {'State': 'Washington', 'Year': 1984, 'County': 'Stevens', 'Party': 'R'},
#  {'State': 'Washington', 'Year': 1984, 'County': 'Thurston', 'Party': 'R'},
#  {'State': 'Washington', 'Year': 1984, 'County': 'Wahkiakum', 'Party': 'D'},
#  {'State': 'Washington', 'Year': 1984, 'County': 'Walla Walla', 'Party': 'R'},
#  {'State': 'Washington', 'Year': 1984, 'County': 'Whatcom', 'Party': 'R'},
#  {'State': 'Washington', 'Year': 1984, 'County': 'Whitman', 'Party': 'R'},
#  {'State': 'Washington', 'Year': 1984, 'County': 'Yakima', 'Party': 'R'},
#  {'State': 'Washington', 'Year': 1980, 'County': 'Adams', 'Party': 'R'},
#  {'State': 'Washington', 'Year': 1980, 'County': 'Asotin', 'Party': 'R'},
#  {'State': 'Washington', 'Year': 1980, 'County': 'Benton', 'Party': 'R'},
#  {'State': 'Washington', 'Year': 1980, 'County': 'Chelan', 'Party': 'R'},
#  {'State': 'Washington', 'Year': 1980, 'County': 'Clallam', 'Party': 'R'},
#  {'State': 'Washington', 'Year': 1980, 'County': 'Clark', 'Party': 'R'},
#  {'State': 'Washington', 'Year': 1980, 'County': 'Columbia', 'Party': 'R'},
#  {'State': 'Washington', 'Year': 1980, 'County': 'Cowlitz', 'Party': 'R'},
#  {'State': 'Washington', 'Year': 1980, 'County': 'Douglas', 'Party': 'R'},
#  {'State': 'Washington', 'Year': 1980, 'County': 'Ferry', 'Party': 'R'},
#  {'State': 'Washington', 'Year': 1980, 'County': 'Franklin', 'Party': 'R'},
#  {'State': 'Washington', 'Year': 1980, 'County': 'Garfield', 'Party': 'R'},
#  {'State': 'Washington', 'Year': 1980, 'County': 'Grant', 'Party': 'R'},
#  {'State': 'Washington', 'Year': 1980, 'County': 'Grays Harbor', 'Party': 'D'},
#  {'State': 'Washington', 'Year': 1980, 'County': 'Island', 'Party': 'R'},
#  {'State': 'Washington', 'Year': 1980, 'County': 'Jefferson', 'Party': 'R'},
#  {'State': 'Washington', 'Year': 1980, 'County': 'King', 'Party': 'R'},
#  {'State': 'Washington', 'Year': 1980, 'County': 'Kitsap', 'Party': 'R'},
#  {'State': 'Washington', 'Year': 1980, 'County': 'Kittitas', 'Party': 'R'},
#  {'State': 'Washington', 'Year': 1980, 'County': 'Klickitat', 'Party': 'R'},
#  {'State': 'Washington', 'Year': 1980, 'County': 'Lewis', 'Party': 'R'},
#  {'State': 'Washington', 'Year': 1980, 'County': 'Lincoln', 'Party': 'R'},
#  {'State': 'Washington', 'Year': 1980, 'County': 'Mason', 'Party': 'R'},
#  {'State': 'Washington', 'Year': 1980, 'County': 'Okanogan', 'Party': 'R'},
#  {'State': 'Washington', 'Year': 1980, 'County': 'Pacific', 'Party': 'D'},
#  {'State': 'Washington', 'Year': 1980, 'County': 'Pend Oreille', 'Party': 'R'},
#  {'State': 'Washington', 'Year': 1980, 'County': 'Pierce', 'Party': 'R'},
#  {'State': 'Washington', 'Year': 1980, 'County': 'San Juan', 'Party': 'R'},
#  {'State': 'Washington', 'Year': 1980, 'County': 'Skagit', 'Party': 'R'},
#  {'State': 'Washington', 'Year': 1980, 'County': 'Skamania', 'Party': 'R'},
#  {'State': 'Washington', 'Year': 1980, 'County': 'Snohomish', 'Party': 'R'},
#  {'State': 'Washington', 'Year': 1980, 'County': 'Spokane', 'Party': 'R'},
#  {'State': 'Washington', 'Year': 1980, 'County': 'Stevens', 'Party': 'R'},
#  {'State': 'Washington', 'Year': 1980, 'County': 'Thurston', 'Party': 'R'},
#  {'State': 'Washington', 'Year': 1980, 'County': 'Wahkiakum', 'Party': 'R'},
#  {'State': 'Washington', 'Year': 1980, 'County': 'Walla Walla', 'Party': 'R'},
#  {'State': 'Washington', 'Year': 1980, 'County': 'Whatcom', 'Party': 'R'},
#  {'State': 'Washington', 'Year': 1980, 'County': 'Whitman', 'Party': 'R'},
#  {'State': 'Washington', 'Year': 1980, 'County': 'Yakima', 'Party': 'R'},
#  {'State': 'Washington', 'Year': 1976, 'County': 'Adams', 'Party': 'R'},
#  {'State': 'Washington', 'Year': 1976, 'County': 'Asotin', 'Party': 'D'},
#  {'State': 'Washington', 'Year': 1976, 'County': 'Benton', 'Party': 'R'},
#  {'State': 'Washington', 'Year': 1976, 'County': 'Chelan', 'Party': 'R'},
#  {'State': 'Washington', 'Year': 1976, 'County': 'Clallam', 'Party': 'R'},
#  {'State': 'Washington', 'Year': 1976, 'County': 'Clark', 'Party': 'D'},
#  {'State': 'Washington', 'Year': 1976, 'County': 'Columbia', 'Party': 'R'},
#  {'State': 'Washington', 'Year': 1976, 'County': 'Cowlitz', 'Party': 'D'},
#  {'State': 'Washington', 'Year': 1976, 'County': 'Douglas', 'Party': 'R'},
#  {'State': 'Washington', 'Year': 1976, 'County': 'Ferry', 'Party': 'D'},
#  {'State': 'Washington', 'Year': 1976, 'County': 'Franklin', 'Party': 'R'},
#  {'State': 'Washington', 'Year': 1976, 'County': 'Garfield', 'Party': 'R'},
#  {'State': 'Washington', 'Year': 1976, 'County': 'Grant', 'Party': 'R'},
#  {'State': 'Washington', 'Year': 1976, 'County': 'Grays Harbor', 'Party': 'D'},
#  {'State': 'Washington', 'Year': 1976, 'County': 'Island', 'Party': 'R'},
#  {'State': 'Washington', 'Year': 1976, 'County': 'Jefferson', 'Party': 'D'},
#  {'State': 'Washington', 'Year': 1976, 'County': 'King', 'Party': 'R'},
#  {'State': 'Washington', 'Year': 1976, 'County': 'Kitsap', 'Party': 'D'},
#  {'State': 'Washington', 'Year': 1976, 'County': 'Kittitas', 'Party': 'D'},
#  {'State': 'Washington', 'Year': 1976, 'County': 'Klickitat', 'Party': 'D'},
#  {'State': 'Washington', 'Year': 1976, 'County': 'Lewis', 'Party': 'R'},
#  {'State': 'Washington', 'Year': 1976, 'County': 'Lincoln', 'Party': 'R'},
#  {'State': 'Washington', 'Year': 1976, 'County': 'Mason', 'Party': 'D'},
#  {'State': 'Washington', 'Year': 1976, 'County': 'Okanogan', 'Party': 'D'},
#  {'State': 'Washington', 'Year': 1976, 'County': 'Pacific', 'Party': 'D'},
#  {'State': 'Washington', 'Year': 1976, 'County': 'Pend Oreille', 'Party': 'D'},
#  {'State': 'Washington', 'Year': 1976, 'County': 'Pierce', 'Party': 'D'},
#  {'State': 'Washington', 'Year': 1976, 'County': 'San Juan', 'Party': 'R'},
#  {'State': 'Washington', 'Year': 1976, 'County': 'Skagit', 'Party': 'R'},
#  {'State': 'Washington', 'Year': 1976, 'County': 'Skamania', 'Party': 'D'},
#  {'State': 'Washington', 'Year': 1976, 'County': 'Snohomish', 'Party': 'D'},
#  {'State': 'Washington', 'Year': 1976, 'County': 'Spokane', 'Party': 'R'},
#  {'State': 'Washington', 'Year': 1976, 'County': 'Stevens', 'Party': 'R'},
#  {'State': 'Washington', 'Year': 1976, 'County': 'Thurston', 'Party': 'D'},
#  {'State': 'Washington', 'Year': 1976, 'County': 'Wahkiakum', 'Party': 'D'},
#  {'State': 'Washington', 'Year': 1976, 'County': 'Walla Walla', 'Party': 'R'},
#  {'State': 'Washington', 'Year': 1976, 'County': 'Whatcom', 'Party': 'R'},
#  {'State': 'Washington', 'Year': 1976, 'County': 'Whitman', 'Party': 'R'},
#  {'State': 'Washington', 'Year': 1976, 'County': 'Yakima', 'Party': 'R'},
#  {'State': 'Washington', 'Year': 1972, 'County': 'Adams', 'Party': 'R'},
#  {'State': 'Washington', 'Year': 1972, 'County': 'Asotin', 'Party': 'R'},
#  {'State': 'Washington', 'Year': 1972, 'County': 'Benton', 'Party': 'R'},
#  {'State': 'Washington', 'Year': 1972, 'County': 'Chelan', 'Party': 'R'},
#  {'State': 'Washington', 'Year': 1972, 'County': 'Clallam', 'Party': 'R'},
#  {'State': 'Washington', 'Year': 1972, 'County': 'Clark', 'Party': 'R'},
#  {'State': 'Washington', 'Year': 1972, 'County': 'Columbia', 'Party': 'R'},
#  {'State': 'Washington', 'Year': 1972, 'County': 'Cowlitz', 'Party': 'R'},
#  {'State': 'Washington', 'Year': 1972, 'County': 'Douglas', 'Party': 'R'},
#  {'State': 'Washington', 'Year': 1972, 'County': 'Ferry', 'Party': 'R'},
#  {'State': 'Washington', 'Year': 1972, 'County': 'Franklin', 'Party': 'R'},
#  {'State': 'Washington', 'Year': 1972, 'County': 'Garfield', 'Party': 'R'},
#  {'State': 'Washington', 'Year': 1972, 'County': 'Grant', 'Party': 'R'},
#  {'State': 'Washington', 'Year': 1972, 'County': 'Grays Harbor', 'Party': 'D'},
#  {'State': 'Washington', 'Year': 1972, 'County': 'Island', 'Party': 'R'},
#  {'State': 'Washington', 'Year': 1972, 'County': 'Jefferson', 'Party': 'R'},
#  {'State': 'Washington', 'Year': 1972, 'County': 'King', 'Party': 'R'},
#  {'State': 'Washington', 'Year': 1972, 'County': 'Kitsap', 'Party': 'R'},
#  {'State': 'Washington', 'Year': 1972, 'County': 'Kittitas', 'Party': 'R'},
#  {'State': 'Washington', 'Year': 1972, 'County': 'Klickitat', 'Party': 'R'},
#  {'State': 'Washington', 'Year': 1972, 'County': 'Lewis', 'Party': 'R'},
#  {'State': 'Washington', 'Year': 1972, 'County': 'Lincoln', 'Party': 'R'},
#  {'State': 'Washington', 'Year': 1972, 'County': 'Mason', 'Party': 'R'},
#  {'State': 'Washington', 'Year': 1972, 'County': 'Okanogan', 'Party': 'R'},
#  {'State': 'Washington', 'Year': 1972, 'County': 'Pacific', 'Party': 'D'},
#  {'State': 'Washington', 'Year': 1972, 'County': 'Pend Oreille', 'Party': 'R'},
#  {'State': 'Washington', 'Year': 1972, 'County': 'Pierce', 'Party': 'R'},
#  {'State': 'Washington', 'Year': 1972, 'County': 'San Juan', 'Party': 'R'},
#  {'State': 'Washington', 'Year': 1972, 'County': 'Skagit', 'Party': 'R'},
#  {'State': 'Washington', 'Year': 1972, 'County': 'Skamania', 'Party': 'R'},
#  {'State': 'Washington', 'Year': 1972, 'County': 'Snohomish', 'Party': 'R'},
#  {'State': 'Washington', 'Year': 1972, 'County': 'Spokane', 'Party': 'R'},
#  {'State': 'Washington', 'Year': 1972, 'County': 'Stevens', 'Party': 'R'},
#  {'State': 'Washington', 'Year': 1972, 'County': 'Thurston', 'Party': 'R'},
#  {'State': 'Washington', 'Year': 1972, 'County': 'Wahkiakum', 'Party': 'R'},
#  {'State': 'Washington', 'Year': 1972, 'County': 'Walla Walla', 'Party': 'R'},
#  {'State': 'Washington', 'Year': 1972, 'County': 'Whatcom', 'Party': 'R'},
#  {'State': 'Washington', 'Year': 1972, 'County': 'Whitman', 'Party': 'R'},
#  {'State': 'Washington', 'Year': 1972, 'County': 'Yakima', 'Party': 'R'},
#  {'State': 'Washington', 'Year': 1968, 'County': '', 'Party': 'D'},
#  {'State': 'Washington', 'Year': 1968, 'County': '', 'Party': 'D'},
#  {'State': 'Washington', 'Year': 1968, 'County': '', 'Party': 'D'},
#  {'State': 'Washington', 'Year': 1968, 'County': '', 'Party': 'D'},
#  {'State': 'Washington', 'Year': 1968, 'County': '', 'Party': 'D'},
#  {'State': 'Washington', 'Year': 1968, 'County': '', 'Party': 'D'},
#  {'State': 'Washington', 'Year': 1968, 'County': '1,304,281 ', 'Party': 'D'},
#  {'State': 'Washington', 'Year': 1964, 'County': 'Adams', 'Party': 'R'},
#  {'State': 'Washington', 'Year': 1964, 'County': 'Asotin', 'Party': 'D'},
#  {'State': 'Washington', 'Year': 1964, 'County': 'Benton', 'Party': 'D'},
#  {'State': 'Washington', 'Year': 1964, 'County': 'Chelan', 'Party': 'D'},
#  {'State': 'Washington', 'Year': 1964, 'County': 'Clallam', 'Party': 'D'},
#  {'State': 'Washington', 'Year': 1964, 'County': 'Clark', 'Party': 'D'},
#  {'State': 'Washington', 'Year': 1964, 'County': 'Columbia', 'Party': 'D'},
#  {'State': 'Washington', 'Year': 1964, 'County': 'Cowlitz', 'Party': 'D'},
#  {'State': 'Washington', 'Year': 1964, 'County': 'Douglas', 'Party': 'D'},
#  {'State': 'Washington', 'Year': 1964, 'County': 'Ferry', 'Party': 'D'},
#  {'State': 'Washington', 'Year': 1964, 'County': 'Franklin', 'Party': 'D'},
#  {'State': 'Washington', 'Year': 1964, 'County': 'Garfield', 'Party': 'D'},
#  {'State': 'Washington', 'Year': 1964, 'County': 'Grant', 'Party': 'D'},
#  {'State': 'Washington', 'Year': 1964, 'County': 'Grays Harbor', 'Party': 'D'},
#  {'State': 'Washington', 'Year': 1964, 'County': 'Island', 'Party': 'D'},
#  {'State': 'Washington', 'Year': 1964, 'County': 'Jefferson', 'Party': 'D'},
#  {'State': 'Washington', 'Year': 1964, 'County': 'King', 'Party': 'D'},
#  {'State': 'Washington', 'Year': 1964, 'County': 'Kitsap', 'Party': 'D'},
#  {'State': 'Washington', 'Year': 1964, 'County': 'Kittitas', 'Party': 'D'},
#  {'State': 'Washington', 'Year': 1964, 'County': 'Klickitat', 'Party': 'D'},
#  {'State': 'Washington', 'Year': 1964, 'County': 'Lewis', 'Party': 'D'},
#  {'State': 'Washington', 'Year': 1964, 'County': 'Lincoln', 'Party': 'R'},
#  {'State': 'Washington', 'Year': 1964, 'County': 'Mason', 'Party': 'D'},
#  {'State': 'Washington', 'Year': 1964, 'County': 'Okanogan', 'Party': 'D'},
#  {'State': 'Washington', 'Year': 1964, 'County': 'Pacific', 'Party': 'D'},
#  {'State': 'Washington', 'Year': 1964, 'County': 'Pend Oreille', 'Party': 'D'},
#  {'State': 'Washington', 'Year': 1964, 'County': 'Pierce', 'Party': 'D'},
#  {'State': 'Washington', 'Year': 1964, 'County': 'San Juan', 'Party': 'D'},
#  {'State': 'Washington', 'Year': 1964, 'County': 'Skagit', 'Party': 'D'},
#  {'State': 'Washington', 'Year': 1964, 'County': 'Skamania', 'Party': 'D'},
#  {'State': 'Washington', 'Year': 1964, 'County': 'Snohomish', 'Party': 'D'},
#  {'State': 'Washington', 'Year': 1964, 'County': 'Spokane', 'Party': 'D'},
#  {'State': 'Washington', 'Year': 1964, 'County': 'Stevens', 'Party': 'D'},
#  {'State': 'Washington', 'Year': 1964, 'County': 'Thurston', 'Party': 'D'},
#  {'State': 'Washington', 'Year': 1964, 'County': 'Wahkiakum', 'Party': 'D'},
#  {'State': 'Washington', 'Year': 1964, 'County': 'Walla Walla', 'Party': 'D'},
#  {'State': 'Washington', 'Year': 1964, 'County': 'Whatcom', 'Party': 'D'},
#  {'State': 'Washington', 'Year': 1964, 'County': 'Whitman', 'Party': 'R'},
#  {'State': 'Washington', 'Year': 1964, 'County': 'Yakima', 'Party': 'D'}]

# %%
LA_result = []
for i in range(10):
    try:
        year = 2000 - 4*i
        http = "https://en.wikipedia.org/wiki/" + str(year) + "_United_States_presidential_election_in_Louisiana"
        f = r.get(http)
        html_content = f.content
        soup = BeautifulSoup(html_content, 'html.parser')
        tables = [table for table in soup.find_all("table")]
        # states_list = []
        # for _ in table.find_all("tr")[2:]:
        #     states_list += [_.find("td").text]
        # return states_list[:-2]
        for _ in tables[12].find_all("tr")[2:]:
            try:
                dict = {}
                county = _.find("td").text.strip('\n')
                party = "R" if _.find("td")['style'].strip('background-color:') == '#FFB6B6' else "D"
                
                dict['State'] = 'Louisiana'
                dict['Year'] = year
                dict['County'] = county
                dict['Party'] = party
                LA_result += [dict]
            except Exception as e:
                print(e)
                pass
    except Exception as e:
        print(e)
        pass
LA_result
# Out:
# 'NoneType' object has no attribute 'text'
# 'NoneType' object has no attribute 'text'
# 'style'
# 'style'
# 'style'
# 'style'
# 'style'
# 'style'
# 'NoneType' object has no attribute 'text'
# 'NoneType' object has no attribute 'text'
# 'NoneType' object has no attribute 'text'
# 'NoneType' object has no attribute 'text'
# 'NoneType' object has no attribute 'text'
# 'NoneType' object has no attribute 'text'
# 'NoneType' object has no attribute 'text'
# [{'State': 'Louisiana', 'Year': 2000, 'County': 'Acadia', 'Party': 'R'},
#  {'State': 'Louisiana', 'Year': 2000, 'County': 'Allen', 'Party': 'R'},
#  {'State': 'Louisiana', 'Year': 2000, 'County': 'Ascension', 'Party': 'R'},
#  {'State': 'Louisiana', 'Year': 2000, 'County': 'Assumption', 'Party': 'D'},
#  {'State': 'Louisiana', 'Year': 2000, 'County': 'Avoyelles', 'Party': 'R'},
#  {'State': 'Louisiana', 'Year': 2000, 'County': 'Beauregard', 'Party': 'R'},
#  {'State': 'Louisiana', 'Year': 2000, 'County': 'Bienville', 'Party': 'D'},
#  {'State': 'Louisiana', 'Year': 2000, 'County': 'Bossier', 'Party': 'R'},
#  {'State': 'Louisiana', 'Year': 2000, 'County': 'Caddo', 'Party': 'D'},
#  {'State': 'Louisiana', 'Year': 2000, 'County': 'Calcasieu', 'Party': 'R'},
#  {'State': 'Louisiana', 'Year': 2000, 'County': 'Caldwell', 'Party': 'R'},
#  {'State': 'Louisiana', 'Year': 2000, 'County': 'Cameron', 'Party': 'R'},
#  {'State': 'Louisiana', 'Year': 2000, 'County': 'Catahoula', 'Party': 'R'},
#  {'State': 'Louisiana', 'Year': 2000, 'County': 'Claiborne', 'Party': 'R'},
#  {'State': 'Louisiana', 'Year': 2000, 'County': 'Concordia', 'Party': 'R'},
#  {'State': 'Louisiana', 'Year': 2000, 'County': 'DeSoto', 'Party': 'R'},
#  {'State': 'Louisiana',
#   'Year': 2000,
#   'County': 'East Baton Rouge',
#   'Party': 'R'},
#  {'State': 'Louisiana', 'Year': 2000, 'County': 'East Carroll', 'Party': 'D'},
#  {'State': 'Louisiana',
#   'Year': 2000,
#   'County': 'East Feliciana',
#   'Party': 'R'},
#  {'State': 'Louisiana', 'Year': 2000, 'County': 'Evangeline', 'Party': 'R'},
#  {'State': 'Louisiana', 'Year': 2000, 'County': 'Franklin', 'Party': 'R'},
#  {'State': 'Louisiana', 'Year': 2000, 'County': 'Grant', 'Party': 'R'},
#  {'State': 'Louisiana', 'Year': 2000, 'County': 'Iberia', 'Party': 'R'},
#  {'State': 'Louisiana', 'Year': 2000, 'County': 'Iberville', 'Party': 'D'},
#  {'State': 'Louisiana', 'Year': 2000, 'County': 'Jackson', 'Party': 'R'},
#  {'State': 'Louisiana', 'Year': 2000, 'County': 'Jefferson', 'Party': 'R'},
#  {'State': 'Louisiana',
#   'Year': 2000,
#   'County': 'Jefferson Davis',
#   'Party': 'R'},
#  {'State': 'Louisiana', 'Year': 2000, 'County': 'Lafayette', 'Party': 'R'},
#  {'State': 'Louisiana', 'Year': 2000, 'County': 'Lafourche', 'Party': 'R'},
#  {'State': 'Louisiana', 'Year': 2000, 'County': 'LaSalle', 'Party': 'R'},
#  {'State': 'Louisiana', 'Year': 2000, 'County': 'Lincoln', 'Party': 'R'},
#  {'State': 'Louisiana', 'Year': 2000, 'County': 'Livingston', 'Party': 'R'},
#  {'State': 'Louisiana', 'Year': 2000, 'County': 'Madison', 'Party': 'D'},
#  {'State': 'Louisiana', 'Year': 2000, 'County': 'Morehouse', 'Party': 'R'},
#  {'State': 'Louisiana', 'Year': 2000, 'County': 'Natchitoches', 'Party': 'R'},
#  {'State': 'Louisiana', 'Year': 2000, 'County': 'Orleans', 'Party': 'D'},
#  {'State': 'Louisiana', 'Year': 2000, 'County': 'Ouachita', 'Party': 'R'},
#  {'State': 'Louisiana', 'Year': 2000, 'County': 'Plaquemines', 'Party': 'R'},
#  {'State': 'Louisiana', 'Year': 2000, 'County': 'Pointe Coupee', 'Party': 'D'},
#  {'State': 'Louisiana', 'Year': 2000, 'County': 'Rapides', 'Party': 'R'},
#  {'State': 'Louisiana', 'Year': 2000, 'County': 'Red River', 'Party': 'R'},
#  {'State': 'Louisiana', 'Year': 2000, 'County': 'Richland', 'Party': 'R'},
#  {'State': 'Louisiana', 'Year': 2000, 'County': 'Sabine', 'Party': 'R'},
#  {'State': 'Louisiana', 'Year': 2000, 'County': 'St. Bernard', 'Party': 'R'},
#  {'State': 'Louisiana', 'Year': 2000, 'County': 'St. Charles', 'Party': 'R'},
#  {'State': 'Louisiana', 'Year': 2000, 'County': 'St. Helena', 'Party': 'D'},
#  {'State': 'Louisiana', 'Year': 2000, 'County': 'St. James', 'Party': 'D'},
#  {'State': 'Louisiana',
#   'Year': 2000,
#   'County': 'St. John the Baptist',
#   'Party': 'D'},
#  {'State': 'Louisiana', 'Year': 2000, 'County': 'St. Landry', 'Party': 'D'},
#  {'State': 'Louisiana', 'Year': 2000, 'County': 'St. Martin', 'Party': 'R'},
#  {'State': 'Louisiana', 'Year': 2000, 'County': 'St. Mary', 'Party': 'R'},
#  {'State': 'Louisiana', 'Year': 2000, 'County': 'St. Tammany', 'Party': 'R'},
#  {'State': 'Louisiana', 'Year': 2000, 'County': 'Tangipahoa', 'Party': 'R'},
#  {'State': 'Louisiana', 'Year': 2000, 'County': 'Tensas', 'Party': 'D'},
#  {'State': 'Louisiana', 'Year': 2000, 'County': 'Terrebonne', 'Party': 'R'},
#  {'State': 'Louisiana', 'Year': 2000, 'County': 'Union', 'Party': 'R'},
#  {'State': 'Louisiana', 'Year': 2000, 'County': 'Vermilion', 'Party': 'R'},
#  {'State': 'Louisiana', 'Year': 2000, 'County': 'Vernon', 'Party': 'R'},
#  {'State': 'Louisiana', 'Year': 2000, 'County': 'Washington', 'Party': 'R'},
#  {'State': 'Louisiana', 'Year': 2000, 'County': 'Webster', 'Party': 'R'},
#  {'State': 'Louisiana',
#   'Year': 2000,
#   'County': 'West Baton Rouge',
#   'Party': 'D'},
#  {'State': 'Louisiana', 'Year': 2000, 'County': 'West Carroll', 'Party': 'R'},
#  {'State': 'Louisiana',
#   'Year': 2000,
#   'County': 'West Feliciana',
#   'Party': 'R'},
#  {'State': 'Louisiana', 'Year': 2000, 'County': 'Winn', 'Party': 'R'},
#  {'State': 'Louisiana', 'Year': 1996, 'County': 'Acadia', 'Party': 'D'},
#  {'State': 'Louisiana', 'Year': 1996, 'County': 'Allen', 'Party': 'D'},
#  {'State': 'Louisiana', 'Year': 1996, 'County': 'Ascension', 'Party': 'D'},
#  {'State': 'Louisiana', 'Year': 1996, 'County': 'Assumption', 'Party': 'D'},
#  {'State': 'Louisiana', 'Year': 1996, 'County': 'Avoyelles', 'Party': 'D'},
#  {'State': 'Louisiana', 'Year': 1996, 'County': 'Beauregard', 'Party': 'R'},
#  {'State': 'Louisiana', 'Year': 1996, 'County': 'Bienville', 'Party': 'D'},
#  {'State': 'Louisiana', 'Year': 1996, 'County': 'Bossier', 'Party': 'R'},
#  {'State': 'Louisiana', 'Year': 1996, 'County': 'Caddo', 'Party': 'D'},
#  {'State': 'Louisiana', 'Year': 1996, 'County': 'Calcasieu', 'Party': 'D'},
#  {'State': 'Louisiana', 'Year': 1996, 'County': 'Caldwell', 'Party': 'D'},
#  {'State': 'Louisiana', 'Year': 1996, 'County': 'Cameron', 'Party': 'D'},
#  {'State': 'Louisiana', 'Year': 1996, 'County': 'Catahoula', 'Party': 'D'},
#  {'State': 'Louisiana', 'Year': 1996, 'County': 'Claiborne', 'Party': 'D'},
#  {'State': 'Louisiana', 'Year': 1996, 'County': 'Concordia', 'Party': 'D'},
#  {'State': 'Louisiana', 'Year': 1996, 'County': 'DeSoto', 'Party': 'D'},
#  {'State': 'Louisiana',
#   'Year': 1996,
#   'County': 'East Baton Rouge',
#   'Party': 'D'},
#  {'State': 'Louisiana', 'Year': 1996, 'County': 'East Carroll', 'Party': 'D'},
#  {'State': 'Louisiana',
#   'Year': 1996,
#   'County': 'East Feliciana',
#   'Party': 'D'},
#  {'State': 'Louisiana', 'Year': 1996, 'County': 'Evangeline', 'Party': 'D'},
#  {'State': 'Louisiana', 'Year': 1996, 'County': 'Franklin', 'Party': 'D'},
#  {'State': 'Louisiana', 'Year': 1996, 'County': 'Grant', 'Party': 'R'},
#  {'State': 'Louisiana', 'Year': 1996, 'County': 'Iberia', 'Party': 'D'},
#  {'State': 'Louisiana', 'Year': 1996, 'County': 'Iberville', 'Party': 'D'},
#  {'State': 'Louisiana', 'Year': 1996, 'County': 'Jackson', 'Party': 'D'},
#  {'State': 'Louisiana', 'Year': 1996, 'County': 'Jefferson', 'Party': 'R'},
#  {'State': 'Louisiana',
#   'Year': 1996,
#   'County': 'Jefferson Davis',
#   'Party': 'D'},
#  {'State': 'Louisiana', 'Year': 1996, 'County': 'Lafayette', 'Party': 'R'},
#  {'State': 'Louisiana', 'Year': 1996, 'County': 'Lafourche', 'Party': 'D'},
#  {'State': 'Louisiana', 'Year': 1996, 'County': 'LaSalle', 'Party': 'R'},
#  {'State': 'Louisiana', 'Year': 1996, 'County': 'Lincoln', 'Party': 'D'},
#  {'State': 'Louisiana', 'Year': 1996, 'County': 'Livingston', 'Party': 'R'},
#  {'State': 'Louisiana', 'Year': 1996, 'County': 'Madison', 'Party': 'D'},
#  {'State': 'Louisiana', 'Year': 1996, 'County': 'Morehouse', 'Party': 'D'},
#  {'State': 'Louisiana', 'Year': 1996, 'County': 'Natchitoches', 'Party': 'D'},
#  {'State': 'Louisiana', 'Year': 1996, 'County': 'Orleans', 'Party': 'D'},
#  {'State': 'Louisiana', 'Year': 1996, 'County': 'Ouachita', 'Party': 'R'},
#  {'State': 'Louisiana', 'Year': 1996, 'County': 'Plaquemines', 'Party': 'D'},
#  {'State': 'Louisiana', 'Year': 1996, 'County': 'Pointe Coupee', 'Party': 'D'},
#  {'State': 'Louisiana', 'Year': 1996, 'County': 'Rapides', 'Party': 'D'},
#  {'State': 'Louisiana', 'Year': 1996, 'County': 'Red River', 'Party': 'D'},
#  {'State': 'Louisiana', 'Year': 1996, 'County': 'Richland', 'Party': 'D'},
#  {'State': 'Louisiana', 'Year': 1996, 'County': 'Sabine', 'Party': 'D'},
#  {'State': 'Louisiana', 'Year': 1996, 'County': 'St. Bernard', 'Party': 'D'},
#  {'State': 'Louisiana', 'Year': 1996, 'County': 'St. Charles', 'Party': 'D'},
#  {'State': 'Louisiana', 'Year': 1996, 'County': 'St. Helena', 'Party': 'D'},
#  {'State': 'Louisiana', 'Year': 1996, 'County': 'St. James', 'Party': 'D'},
#  {'State': 'Louisiana',
#   'Year': 1996,
#   'County': 'St. John the Baptist',
#   'Party': 'D'},
#  {'State': 'Louisiana', 'Year': 1996, 'County': 'St. Landry', 'Party': 'D'},
#  {'State': 'Louisiana', 'Year': 1996, 'County': 'St. Martin', 'Party': 'D'},
#  {'State': 'Louisiana', 'Year': 1996, 'County': 'St. Mary', 'Party': 'D'},
#  {'State': 'Louisiana', 'Year': 1996, 'County': 'St. Tammany', 'Party': 'R'},
#  {'State': 'Louisiana', 'Year': 1996, 'County': 'Tangipahoa', 'Party': 'D'},
#  {'State': 'Louisiana', 'Year': 1996, 'County': 'Tensas', 'Party': 'D'},
#  {'State': 'Louisiana', 'Year': 1996, 'County': 'Terrebonne', 'Party': 'D'},
#  {'State': 'Louisiana', 'Year': 1996, 'County': 'Union', 'Party': 'R'},
#  {'State': 'Louisiana', 'Year': 1996, 'County': 'Vermilion', 'Party': 'D'},
#  {'State': 'Louisiana', 'Year': 1996, 'County': 'Vernon', 'Party': 'D'},
#  {'State': 'Louisiana', 'Year': 1996, 'County': 'Washington', 'Party': 'D'},
#  {'State': 'Louisiana', 'Year': 1996, 'County': 'Webster', 'Party': 'D'},
#  {'State': 'Louisiana',
#   'Year': 1996,
#   'County': 'West Baton Rouge',
#   'Party': 'D'},
#  {'State': 'Louisiana', 'Year': 1996, 'County': 'West Carroll', 'Party': 'R'},
#  {'State': 'Louisiana',
#   'Year': 1996,
#   'County': 'West Feliciana',
#   'Party': 'D'},
#  {'State': 'Louisiana', 'Year': 1996, 'County': 'Winn', 'Party': 'D'},
#  {'State': 'Louisiana', 'Year': 1988, 'County': 'Al Gore', 'Party': 'D'},
#  {'State': 'Louisiana',
#   'Year': 1988,
#   'County': 'Michael Dukakis',
#   'Party': 'D'},
#  {'State': 'Louisiana', 'Year': 1988, 'County': 'Dick Gephardt', 'Party': 'D'},
#  {'State': 'Louisiana', 'Year': 1988, 'County': 'Gary Hart', 'Party': 'D'},
#  {'State': 'Louisiana', 'Year': 1988, 'County': 'David Duke', 'Party': 'D'},
#  {'State': 'Louisiana', 'Year': 1988, 'County': 'Paul Simon', 'Party': 'D'},
#  {'State': 'Louisiana', 'Year': 1988, 'County': 'Frank Ahern', 'Party': 'D'},
#  {'State': 'Louisiana',
#   'Year': 1988,
#   'County': 'Bruce Babbitt (withdrawn)',
#   'Party': 'D'},
#  {'State': 'Louisiana',
#   'Year': 1988,
#   'County': 'Lyndon LaRouche',
#   'Party': 'D'},
#  {'State': 'Louisiana',
#   'Year': 1988,
#   'County': 'Norbert G. Dennerll Jr.',
#   'Party': 'D'},
#  {'State': 'Louisiana',
#   'Year': 1988,
#   'County': 'Richard B. Kay',
#   'Party': 'D'},
#  {'State': 'Louisiana', 'Year': 1984, 'County': 'Acadia', 'Party': 'R'},
#  {'State': 'Louisiana', 'Year': 1984, 'County': 'Allen', 'Party': 'D'},
#  {'State': 'Louisiana', 'Year': 1984, 'County': 'Ascension', 'Party': 'R'},
#  {'State': 'Louisiana', 'Year': 1984, 'County': 'Assumption', 'Party': 'R'},
#  {'State': 'Louisiana', 'Year': 1984, 'County': 'Avoyelles', 'Party': 'R'},
#  {'State': 'Louisiana', 'Year': 1984, 'County': 'Beauregard', 'Party': 'R'},
#  {'State': 'Louisiana', 'Year': 1984, 'County': 'Bienville', 'Party': 'R'},
#  {'State': 'Louisiana', 'Year': 1984, 'County': 'Bossier', 'Party': 'R'},
#  {'State': 'Louisiana', 'Year': 1984, 'County': 'Caddo', 'Party': 'R'},
#  {'State': 'Louisiana', 'Year': 1984, 'County': 'Calcasieu', 'Party': 'R'},
#  {'State': 'Louisiana', 'Year': 1984, 'County': 'Caldwell', 'Party': 'R'},
#  {'State': 'Louisiana', 'Year': 1984, 'County': 'Cameron', 'Party': 'R'},
#  {'State': 'Louisiana', 'Year': 1984, 'County': 'Catahoula', 'Party': 'R'},
#  {'State': 'Louisiana', 'Year': 1984, 'County': 'Claiborne', 'Party': 'R'},
#  {'State': 'Louisiana', 'Year': 1984, 'County': 'Concordia', 'Party': 'R'},
#  {'State': 'Louisiana', 'Year': 1984, 'County': 'DeSoto', 'Party': 'R'},
#  {'State': 'Louisiana',
#   'Year': 1984,
#   'County': 'East Baton Rouge',
#   'Party': 'R'},
#  {'State': 'Louisiana', 'Year': 1984, 'County': 'East Carroll', 'Party': 'D'},
#  {'State': 'Louisiana',
#   'Year': 1984,
#   'County': 'East Feliciana',
#   'Party': 'R'},
#  {'State': 'Louisiana', 'Year': 1984, 'County': 'Evangeline', 'Party': 'R'},
#  {'State': 'Louisiana', 'Year': 1984, 'County': 'Franklin', 'Party': 'R'},
#  {'State': 'Louisiana', 'Year': 1984, 'County': 'Grant', 'Party': 'R'},
#  {'State': 'Louisiana', 'Year': 1984, 'County': 'Iberia', 'Party': 'R'},
#  {'State': 'Louisiana', 'Year': 1984, 'County': 'Iberville', 'Party': 'D'},
#  {'State': 'Louisiana', 'Year': 1984, 'County': 'Jackson', 'Party': 'R'},
#  {'State': 'Louisiana', 'Year': 1984, 'County': 'Jefferson', 'Party': 'R'},
#  {'State': 'Louisiana',
#   'Year': 1984,
#   'County': 'Jefferson Davis',
#   'Party': 'R'},
#  {'State': 'Louisiana', 'Year': 1984, 'County': 'Lafayette', 'Party': 'R'},
#  {'State': 'Louisiana', 'Year': 1984, 'County': 'Lafourche', 'Party': 'R'},
#  {'State': 'Louisiana', 'Year': 1984, 'County': 'LaSalle', 'Party': 'R'},
#  {'State': 'Louisiana', 'Year': 1984, 'County': 'Lincoln', 'Party': 'R'},
#  {'State': 'Louisiana', 'Year': 1984, 'County': 'Livingston', 'Party': 'R'},
#  {'State': 'Louisiana', 'Year': 1984, 'County': 'Madison', 'Party': 'D'},
#  {'State': 'Louisiana', 'Year': 1984, 'County': 'Morehouse', 'Party': 'R'},
#  {'State': 'Louisiana', 'Year': 1984, 'County': 'Natchitoches', 'Party': 'R'},
#  {'State': 'Louisiana', 'Year': 1984, 'County': 'Orleans', 'Party': 'D'},
#  {'State': 'Louisiana', 'Year': 1984, 'County': 'Ouachita', 'Party': 'R'},
#  {'State': 'Louisiana', 'Year': 1984, 'County': 'Plaquemines', 'Party': 'R'},
#  {'State': 'Louisiana', 'Year': 1984, 'County': 'Pointe Coupee', 'Party': 'D'},
#  {'State': 'Louisiana', 'Year': 1984, 'County': 'Rapides', 'Party': 'R'},
#  {'State': 'Louisiana', 'Year': 1984, 'County': 'Red River', 'Party': 'R'},
#  {'State': 'Louisiana', 'Year': 1984, 'County': 'Richland', 'Party': 'R'},
#  {'State': 'Louisiana', 'Year': 1984, 'County': 'Sabine', 'Party': 'R'},
#  {'State': 'Louisiana', 'Year': 1984, 'County': 'St. Bernard', 'Party': 'R'},
#  {'State': 'Louisiana', 'Year': 1984, 'County': 'St. Charles', 'Party': 'R'},
#  {'State': 'Louisiana', 'Year': 1984, 'County': 'St. Helena', 'Party': 'D'},
#  {'State': 'Louisiana', 'Year': 1984, 'County': 'St. James', 'Party': 'D'},
#  {'State': 'Louisiana',
#   'Year': 1984,
#   'County': 'St. John the Baptist',
#   'Party': 'R'},
#  {'State': 'Louisiana', 'Year': 1984, 'County': 'St. Landry', 'Party': 'R'},
#  {'State': 'Louisiana', 'Year': 1984, 'County': 'St. Martin', 'Party': 'R'},
#  {'State': 'Louisiana', 'Year': 1984, 'County': 'St. Mary', 'Party': 'R'},
#  {'State': 'Louisiana', 'Year': 1984, 'County': 'St. Tammany', 'Party': 'R'},
#  {'State': 'Louisiana', 'Year': 1984, 'County': 'Tangipahoa', 'Party': 'R'},
#  {'State': 'Louisiana', 'Year': 1984, 'County': 'Tensas', 'Party': 'R'},
#  {'State': 'Louisiana', 'Year': 1984, 'County': 'Terrebonne', 'Party': 'R'},
#  {'State': 'Louisiana', 'Year': 1984, 'County': 'Union', 'Party': 'R'},
#  {'State': 'Louisiana', 'Year': 1984, 'County': 'Vermilion', 'Party': 'R'},
#  {'State': 'Louisiana', 'Year': 1984, 'County': 'Vernon', 'Party': 'R'},
#  {'State': 'Louisiana', 'Year': 1984, 'County': 'Washington', 'Party': 'R'},
#  {'State': 'Louisiana', 'Year': 1984, 'County': 'Webster', 'Party': 'R'},
#  {'State': 'Louisiana',
#   'Year': 1984,
#   'County': 'West Baton Rouge',
#   'Party': 'D'},
#  {'State': 'Louisiana', 'Year': 1984, 'County': 'West Carroll', 'Party': 'R'},
#  {'State': 'Louisiana',
#   'Year': 1984,
#   'County': 'West Feliciana',
#   'Party': 'D'},
#  {'State': 'Louisiana', 'Year': 1984, 'County': 'Winn', 'Party': 'R'},
#  {'State': 'Louisiana', 'Year': 1980, 'County': 'Acadia', 'Party': 'R'},
#  {'State': 'Louisiana', 'Year': 1980, 'County': 'Allen', 'Party': 'D'},
#  {'State': 'Louisiana', 'Year': 1980, 'County': 'Ascension', 'Party': 'D'},
#  {'State': 'Louisiana', 'Year': 1980, 'County': 'Assumption', 'Party': 'D'},
#  {'State': 'Louisiana', 'Year': 1980, 'County': 'Avoyelles', 'Party': 'R'},
#  {'State': 'Louisiana', 'Year': 1980, 'County': 'Beauregard', 'Party': 'D'},
#  {'State': 'Louisiana', 'Year': 1980, 'County': 'Bienville', 'Party': 'D'},
#  {'State': 'Louisiana', 'Year': 1980, 'County': 'Bossier', 'Party': 'R'},
#  {'State': 'Louisiana', 'Year': 1980, 'County': 'Caddo', 'Party': 'R'},
#  {'State': 'Louisiana', 'Year': 1980, 'County': 'Calcasieu', 'Party': 'D'},
#  {'State': 'Louisiana', 'Year': 1980, 'County': 'Caldwell', 'Party': 'R'},
#  {'State': 'Louisiana', 'Year': 1980, 'County': 'Cameron', 'Party': 'D'},
#  {'State': 'Louisiana', 'Year': 1980, 'County': 'Catahoula', 'Party': 'R'},
#  {'State': 'Louisiana', 'Year': 1980, 'County': 'Claiborne', 'Party': 'R'},
#  {'State': 'Louisiana', 'Year': 1980, 'County': 'Concordia', 'Party': 'R'},
#  {'State': 'Louisiana', 'Year': 1980, 'County': 'DeSoto', 'Party': 'D'},
#  {'State': 'Louisiana',
#   'Year': 1980,
#   'County': 'East Baton Rouge',
#   'Party': 'R'},
#  {'State': 'Louisiana', 'Year': 1980, 'County': 'East Carroll', 'Party': 'D'},
#  {'State': 'Louisiana',
#   'Year': 1980,
#   'County': 'East Feliciana',
#   'Party': 'D'},
#  {'State': 'Louisiana', 'Year': 1980, 'County': 'Evangeline', 'Party': 'R'},
#  {'State': 'Louisiana', 'Year': 1980, 'County': 'Franklin', 'Party': 'R'},
#  {'State': 'Louisiana', 'Year': 1980, 'County': 'Grant', 'Party': 'R'},
#  {'State': 'Louisiana', 'Year': 1980, 'County': 'Iberia', 'Party': 'R'},
#  {'State': 'Louisiana', 'Year': 1980, 'County': 'Iberville', 'Party': 'D'},
#  {'State': 'Louisiana', 'Year': 1980, 'County': 'Jackson', 'Party': 'R'},
#  {'State': 'Louisiana', 'Year': 1980, 'County': 'Jefferson', 'Party': 'R'},
#  {'State': 'Louisiana',
#   'Year': 1980,
#   'County': 'Jefferson Davis',
#   'Party': 'D'},
#  {'State': 'Louisiana', 'Year': 1980, 'County': 'Lafayette', 'Party': 'R'},
#  {'State': 'Louisiana', 'Year': 1980, 'County': 'Lafourche', 'Party': 'R'},
#  {'State': 'Louisiana', 'Year': 1980, 'County': 'LaSalle', 'Party': 'R'},
#  {'State': 'Louisiana', 'Year': 1980, 'County': 'Lincoln', 'Party': 'R'},
#  {'State': 'Louisiana', 'Year': 1980, 'County': 'Livingston', 'Party': 'D'},
#  {'State': 'Louisiana', 'Year': 1980, 'County': 'Madison', 'Party': 'D'},
#  {'State': 'Louisiana', 'Year': 1980, 'County': 'Morehouse', 'Party': 'R'},
#  {'State': 'Louisiana', 'Year': 1980, 'County': 'Natchitoches', 'Party': 'D'},
#  {'State': 'Louisiana', 'Year': 1980, 'County': 'Orleans', 'Party': 'D'},
#  {'State': 'Louisiana', 'Year': 1980, 'County': 'Ouachita', 'Party': 'R'},
#  {'State': 'Louisiana', 'Year': 1980, 'County': 'Plaquemines', 'Party': 'R'},
#  {'State': 'Louisiana', 'Year': 1980, 'County': 'Pointe Coupee', 'Party': 'D'},
#  {'State': 'Louisiana', 'Year': 1980, 'County': 'Rapides', 'Party': 'R'},
#  {'State': 'Louisiana', 'Year': 1980, 'County': 'Red River', 'Party': 'D'},
#  {'State': 'Louisiana', 'Year': 1980, 'County': 'Richland', 'Party': 'R'},
#  {'State': 'Louisiana', 'Year': 1980, 'County': 'Sabine', 'Party': 'D'},
#  {'State': 'Louisiana', 'Year': 1980, 'County': 'St. Bernard', 'Party': 'R'},
#  {'State': 'Louisiana', 'Year': 1980, 'County': 'St. Charles', 'Party': 'D'},
#  {'State': 'Louisiana', 'Year': 1980, 'County': 'St. Helena', 'Party': 'D'},
#  {'State': 'Louisiana', 'Year': 1980, 'County': 'St. James', 'Party': 'D'},
#  {'State': 'Louisiana',
#   'Year': 1980,
#   'County': 'St. John the Baptist',
#   'Party': 'D'},
#  {'State': 'Louisiana', 'Year': 1980, 'County': 'St. Landry', 'Party': 'D'},
#  {'State': 'Louisiana', 'Year': 1980, 'County': 'St. Martin', 'Party': 'D'},
#  {'State': 'Louisiana', 'Year': 1980, 'County': 'St. Mary', 'Party': 'D'},
#  {'State': 'Louisiana', 'Year': 1980, 'County': 'St. Tammany', 'Party': 'R'},
#  {'State': 'Louisiana', 'Year': 1980, 'County': 'Tangipahoa', 'Party': 'D'},
#  {'State': 'Louisiana', 'Year': 1980, 'County': 'Tensas', 'Party': 'D'},
#  {'State': 'Louisiana', 'Year': 1980, 'County': 'Terrebonne', 'Party': 'R'},
#  {'State': 'Louisiana', 'Year': 1980, 'County': 'Union', 'Party': 'R'},
#  {'State': 'Louisiana', 'Year': 1980, 'County': 'Vermilion', 'Party': 'R'},
#  {'State': 'Louisiana', 'Year': 1980, 'County': 'Vernon', 'Party': 'D'},
#  {'State': 'Louisiana', 'Year': 1980, 'County': 'Washington', 'Party': 'D'},
#  {'State': 'Louisiana', 'Year': 1980, 'County': 'Webster', 'Party': 'R'},
#  {'State': 'Louisiana',
#   'Year': 1980,
#   'County': 'West Baton Rouge',
#   'Party': 'D'},
#  {'State': 'Louisiana', 'Year': 1980, 'County': 'West Carroll', 'Party': 'R'},
#  {'State': 'Louisiana',
#   'Year': 1980,
#   'County': 'West Feliciana',
#   'Party': 'D'},
#  {'State': 'Louisiana', 'Year': 1980, 'County': 'Winn', 'Party': 'R'},
#  {'State': 'Louisiana', 'Year': 1976, 'County': 'Acadia', 'Party': 'D'},
#  {'State': 'Louisiana', 'Year': 1976, 'County': 'Allen', 'Party': 'D'},
#  {'State': 'Louisiana', 'Year': 1976, 'County': 'Ascension', 'Party': 'D'},
#  {'State': 'Louisiana', 'Year': 1976, 'County': 'Assumption', 'Party': 'D'},
#  {'State': 'Louisiana', 'Year': 1976, 'County': 'Avoyelles', 'Party': 'D'},
#  {'State': 'Louisiana', 'Year': 1976, 'County': 'Beauregard', 'Party': 'D'},
#  {'State': 'Louisiana', 'Year': 1976, 'County': 'Bienville', 'Party': 'D'},
#  {'State': 'Louisiana', 'Year': 1976, 'County': 'Bossier', 'Party': 'R'},
#  {'State': 'Louisiana', 'Year': 1976, 'County': 'Caddo', 'Party': 'R'},
#  {'State': 'Louisiana', 'Year': 1976, 'County': 'Calcasieu', 'Party': 'D'},
#  {'State': 'Louisiana', 'Year': 1976, 'County': 'Caldwell', 'Party': 'R'},
#  {'State': 'Louisiana', 'Year': 1976, 'County': 'Cameron', 'Party': 'D'},
#  {'State': 'Louisiana', 'Year': 1976, 'County': 'Catahoula', 'Party': 'D'},
#  {'State': 'Louisiana', 'Year': 1976, 'County': 'Claiborne', 'Party': 'R'},
#  {'State': 'Louisiana', 'Year': 1976, 'County': 'Concordia', 'Party': 'D'},
#  {'State': 'Louisiana', 'Year': 1976, 'County': 'DeSoto', 'Party': 'D'},
#  {'State': 'Louisiana',
#   'Year': 1976,
#   'County': 'East Baton Rouge',
#   'Party': 'R'},
#  {'State': 'Louisiana', 'Year': 1976, 'County': 'East Carroll', 'Party': 'D'},
#  {'State': 'Louisiana',
#   'Year': 1976,
#   'County': 'East Feliciana',
#   'Party': 'D'},
#  {'State': 'Louisiana', 'Year': 1976, 'County': 'Evangeline', 'Party': 'D'},
#  {'State': 'Louisiana', 'Year': 1976, 'County': 'Franklin', 'Party': 'R'},
#  {'State': 'Louisiana', 'Year': 1976, 'County': 'Grant', 'Party': 'D'},
#  {'State': 'Louisiana', 'Year': 1976, 'County': 'Iberia', 'Party': 'R'},
#  {'State': 'Louisiana', 'Year': 1976, 'County': 'Iberville', 'Party': 'D'},
#  {'State': 'Louisiana', 'Year': 1976, 'County': 'Jackson', 'Party': 'D'},
#  {'State': 'Louisiana', 'Year': 1976, 'County': 'Jefferson', 'Party': 'R'},
#  {'State': 'Louisiana',
#   'Year': 1976,
#   'County': 'Jefferson Davis',
#   'Party': 'D'},
#  {'State': 'Louisiana', 'Year': 1976, 'County': 'Lafayette', 'Party': 'R'},
#  {'State': 'Louisiana', 'Year': 1976, 'County': 'Lafourche', 'Party': 'D'},
#  {'State': 'Louisiana', 'Year': 1976, 'County': 'LaSalle', 'Party': 'R'},
#  {'State': 'Louisiana', 'Year': 1976, 'County': 'Lincoln', 'Party': 'R'},
#  {'State': 'Louisiana', 'Year': 1976, 'County': 'Livingston', 'Party': 'D'},
#  {'State': 'Louisiana', 'Year': 1976, 'County': 'Madison', 'Party': 'D'},
#  {'State': 'Louisiana', 'Year': 1976, 'County': 'Morehouse', 'Party': 'R'},
#  {'State': 'Louisiana', 'Year': 1976, 'County': 'Natchitoches', 'Party': 'D'},
#  {'State': 'Louisiana', 'Year': 1976, 'County': 'Orleans', 'Party': 'D'},
#  {'State': 'Louisiana', 'Year': 1976, 'County': 'Ouachita', 'Party': 'R'},
#  {'State': 'Louisiana', 'Year': 1976, 'County': 'Plaquemines', 'Party': 'R'},
#  {'State': 'Louisiana', 'Year': 1976, 'County': 'Pointe Coupee', 'Party': 'D'},
#  {'State': 'Louisiana', 'Year': 1976, 'County': 'Rapides', 'Party': 'D'},
#  {'State': 'Louisiana', 'Year': 1976, 'County': 'Red River', 'Party': 'D'},
#  {'State': 'Louisiana', 'Year': 1976, 'County': 'Richland', 'Party': 'R'},
#  {'State': 'Louisiana', 'Year': 1976, 'County': 'Sabine', 'Party': 'D'},
#  {'State': 'Louisiana', 'Year': 1976, 'County': 'St. Bernard', 'Party': 'D'},
#  {'State': 'Louisiana', 'Year': 1976, 'County': 'St. Charles', 'Party': 'D'},
#  {'State': 'Louisiana', 'Year': 1976, 'County': 'St. Helena', 'Party': 'D'},
#  {'State': 'Louisiana', 'Year': 1976, 'County': 'St. James', 'Party': 'D'},
#  {'State': 'Louisiana',
#   'Year': 1976,
#   'County': 'St. John the Baptist',
#   'Party': 'D'},
#  {'State': 'Louisiana', 'Year': 1976, 'County': 'St. Landry', 'Party': 'D'},
#  {'State': 'Louisiana', 'Year': 1976, 'County': 'St. Martin', 'Party': 'D'},
#  {'State': 'Louisiana', 'Year': 1976, 'County': 'St. Mary', 'Party': 'D'},
#  {'State': 'Louisiana', 'Year': 1976, 'County': 'St. Tammany', 'Party': 'R'},
#  {'State': 'Louisiana', 'Year': 1976, 'County': 'Tangipahoa', 'Party': 'D'},
#  {'State': 'Louisiana', 'Year': 1976, 'County': 'Tensas', 'Party': 'D'},
#  {'State': 'Louisiana', 'Year': 1976, 'County': 'Terrebonne', 'Party': 'R'},
#  {'State': 'Louisiana', 'Year': 1976, 'County': 'Union', 'Party': 'R'},
#  {'State': 'Louisiana', 'Year': 1976, 'County': 'Vermilion', 'Party': 'D'},
#  {'State': 'Louisiana', 'Year': 1976, 'County': 'Vernon', 'Party': 'D'},
#  {'State': 'Louisiana', 'Year': 1976, 'County': 'Washington', 'Party': 'D'},
#  {'State': 'Louisiana', 'Year': 1976, 'County': 'Webster', 'Party': 'R'},
#  {'State': 'Louisiana',
#   'Year': 1976,
#   'County': 'West Baton Rouge',
#   'Party': 'D'},
#  {'State': 'Louisiana', 'Year': 1976, 'County': 'West Carroll', 'Party': 'D'},
#  {'State': 'Louisiana',
#   'Year': 1976,
#   'County': 'West Feliciana',
#   'Party': 'D'},
#  {'State': 'Louisiana', 'Year': 1976, 'County': 'Winn', 'Party': 'D'},
#  {'State': 'Louisiana', 'Year': 1972, 'County': 'Acadia', 'Party': 'R'},
#  {'State': 'Louisiana', 'Year': 1972, 'County': 'Allen', 'Party': 'R'},
#  {'State': 'Louisiana', 'Year': 1972, 'County': 'Ascension', 'Party': 'R'},
#  {'State': 'Louisiana', 'Year': 1972, 'County': 'Assumption', 'Party': 'R'},
#  {'State': 'Louisiana', 'Year': 1972, 'County': 'Avoyelles', 'Party': 'R'},
#  {'State': 'Louisiana', 'Year': 1972, 'County': 'Beauregard', 'Party': 'R'},
#  {'State': 'Louisiana', 'Year': 1972, 'County': 'Bienville', 'Party': 'R'},
#  {'State': 'Louisiana', 'Year': 1972, 'County': 'Bossier', 'Party': 'R'},
#  {'State': 'Louisiana', 'Year': 1972, 'County': 'Caddo', 'Party': 'R'},
#  {'State': 'Louisiana', 'Year': 1972, 'County': 'Calcasieu', 'Party': 'R'},
#  {'State': 'Louisiana', 'Year': 1972, 'County': 'Caldwell', 'Party': 'R'},
#  {'State': 'Louisiana', 'Year': 1972, 'County': 'Cameron', 'Party': 'R'},
#  {'State': 'Louisiana', 'Year': 1972, 'County': 'Catahoula', 'Party': 'R'},
#  {'State': 'Louisiana', 'Year': 1972, 'County': 'Claiborne', 'Party': 'R'},
#  {'State': 'Louisiana', 'Year': 1972, 'County': 'Concordia', 'Party': 'R'},
#  {'State': 'Louisiana', 'Year': 1972, 'County': 'DeSoto', 'Party': 'R'},
#  {'State': 'Louisiana',
#   'Year': 1972,
#   'County': 'East Baton Rouge',
#   'Party': 'R'},
#  {'State': 'Louisiana', 'Year': 1972, 'County': 'East Carroll', 'Party': 'R'},
#  {'State': 'Louisiana',
#   'Year': 1972,
#   'County': 'East Feliciana',
#   'Party': 'R'},
#  {'State': 'Louisiana', 'Year': 1972, 'County': 'Evangeline', 'Party': 'R'},
#  {'State': 'Louisiana', 'Year': 1972, 'County': 'Franklin', 'Party': 'R'},
#  {'State': 'Louisiana', 'Year': 1972, 'County': 'Grant', 'Party': 'R'},
#  {'State': 'Louisiana', 'Year': 1972, 'County': 'Iberia', 'Party': 'R'},
#  {'State': 'Louisiana', 'Year': 1972, 'County': 'Iberville', 'Party': 'R'},
#  {'State': 'Louisiana', 'Year': 1972, 'County': 'Jackson', 'Party': 'R'},
#  {'State': 'Louisiana', 'Year': 1972, 'County': 'Jefferson', 'Party': 'R'},
#  {'State': 'Louisiana',
#   'Year': 1972,
#   'County': 'Jefferson Davis',
#   'Party': 'R'},
#  {'State': 'Louisiana', 'Year': 1972, 'County': 'Lafayette', 'Party': 'R'},
#  {'State': 'Louisiana', 'Year': 1972, 'County': 'Lafourche', 'Party': 'R'},
#  {'State': 'Louisiana', 'Year': 1972, 'County': 'LaSalle', 'Party': 'R'},
#  {'State': 'Louisiana', 'Year': 1972, 'County': 'Lincoln', 'Party': 'R'},
#  {'State': 'Louisiana', 'Year': 1972, 'County': 'Livingston', 'Party': 'R'},
#  {'State': 'Louisiana', 'Year': 1972, 'County': 'Madison', 'Party': 'R'},
#  {'State': 'Louisiana', 'Year': 1972, 'County': 'Morehouse', 'Party': 'R'},
#  {'State': 'Louisiana', 'Year': 1972, 'County': 'Natchitoches', 'Party': 'R'},
#  {'State': 'Louisiana', 'Year': 1972, 'County': 'Orleans', 'Party': 'R'},
#  {'State': 'Louisiana', 'Year': 1972, 'County': 'Ouachita', 'Party': 'R'},
#  {'State': 'Louisiana', 'Year': 1972, 'County': 'Plaquemines', 'Party': 'R'},
#  {'State': 'Louisiana', 'Year': 1972, 'County': 'Pointe Coupee', 'Party': 'R'},
#  {'State': 'Louisiana', 'Year': 1972, 'County': 'Rapides', 'Party': 'R'},
#  {'State': 'Louisiana', 'Year': 1972, 'County': 'Red River', 'Party': 'R'},
#  {'State': 'Louisiana', 'Year': 1972, 'County': 'Richland', 'Party': 'R'},
#  {'State': 'Louisiana', 'Year': 1972, 'County': 'Sabine', 'Party': 'R'},
#  {'State': 'Louisiana', 'Year': 1972, 'County': 'St. Bernard', 'Party': 'R'},
#  {'State': 'Louisiana', 'Year': 1972, 'County': 'St. Charles', 'Party': 'R'},
#  {'State': 'Louisiana', 'Year': 1972, 'County': 'St. Helena', 'Party': 'R'},
#  {'State': 'Louisiana', 'Year': 1972, 'County': 'St. James', 'Party': 'R'},
#  {'State': 'Louisiana',
#   'Year': 1972,
#   'County': 'St. John the Baptist',
#   'Party': 'R'},
#  {'State': 'Louisiana', 'Year': 1972, 'County': 'St. Landry', 'Party': 'R'},
#  {'State': 'Louisiana', 'Year': 1972, 'County': 'St. Martin', 'Party': 'R'},
#  {'State': 'Louisiana', 'Year': 1972, 'County': 'St. Mary', 'Party': 'R'},
#  {'State': 'Louisiana', 'Year': 1972, 'County': 'St. Tammany', 'Party': 'R'},
#  {'State': 'Louisiana', 'Year': 1972, 'County': 'Tangipahoa', 'Party': 'R'},
#  {'State': 'Louisiana', 'Year': 1972, 'County': 'Tensas', 'Party': 'R'},
#  {'State': 'Louisiana', 'Year': 1972, 'County': 'Terrebonne', 'Party': 'R'},
#  {'State': 'Louisiana', 'Year': 1972, 'County': 'Union', 'Party': 'R'},
#  {'State': 'Louisiana', 'Year': 1972, 'County': 'Vermilion', 'Party': 'R'},
#  {'State': 'Louisiana', 'Year': 1972, 'County': 'Vernon', 'Party': 'R'},
#  {'State': 'Louisiana', 'Year': 1972, 'County': 'Washington', 'Party': 'R'},
#  {'State': 'Louisiana', 'Year': 1972, 'County': 'Webster', 'Party': 'R'},
#  {'State': 'Louisiana',
#   'Year': 1972,
#   'County': 'West Baton Rouge',
#   'Party': 'R'},
#  {'State': 'Louisiana', 'Year': 1972, 'County': 'West Carroll', 'Party': 'R'},
#  {'State': 'Louisiana',
#   'Year': 1972,
#   'County': 'West Feliciana',
#   'Party': 'D'},
#  {'State': 'Louisiana', 'Year': 1972, 'County': 'Winn', 'Party': 'R'},
#  {'State': 'Louisiana', 'Year': 1968, 'County': 'Acadia', 'Party': 'D'},
#  {'State': 'Louisiana', 'Year': 1968, 'County': 'Allen', 'Party': 'D'},
#  {'State': 'Louisiana', 'Year': 1968, 'County': 'Ascension', 'Party': 'D'},
#  {'State': 'Louisiana', 'Year': 1968, 'County': 'Assumption', 'Party': 'D'},
#  {'State': 'Louisiana', 'Year': 1968, 'County': 'Avoyelles', 'Party': 'D'},
#  {'State': 'Louisiana', 'Year': 1968, 'County': 'Beauregard', 'Party': 'D'},
#  {'State': 'Louisiana', 'Year': 1968, 'County': 'Bienville', 'Party': 'D'},
#  {'State': 'Louisiana', 'Year': 1968, 'County': 'Bossier', 'Party': 'D'},
#  {'State': 'Louisiana', 'Year': 1968, 'County': 'Caddo', 'Party': 'D'},
#  {'State': 'Louisiana', 'Year': 1968, 'County': 'Calcasieu', 'Party': 'D'},
#  {'State': 'Louisiana', 'Year': 1968, 'County': 'Caldwell', 'Party': 'D'},
#  {'State': 'Louisiana', 'Year': 1968, 'County': 'Cameron', 'Party': 'D'},
#  {'State': 'Louisiana', 'Year': 1968, 'County': 'Catahoula', 'Party': 'D'},
#  {'State': 'Louisiana', 'Year': 1968, 'County': 'Claiborne', 'Party': 'D'},
#  {'State': 'Louisiana', 'Year': 1968, 'County': 'Concordia', 'Party': 'D'},
#  {'State': 'Louisiana', 'Year': 1968, 'County': 'DeSoto', 'Party': 'D'},
#  {'State': 'Louisiana',
#   'Year': 1968,
#   'County': 'East Baton Rouge',
#   'Party': 'D'},
#  {'State': 'Louisiana', 'Year': 1968, 'County': 'East Carroll', 'Party': 'D'},
#  {'State': 'Louisiana',
#   'Year': 1968,
#   'County': 'East Feliciana',
#   'Party': 'D'},
#  {'State': 'Louisiana', 'Year': 1968, 'County': 'Evangeline', 'Party': 'D'},
#  {'State': 'Louisiana', 'Year': 1968, 'County': 'Franklin', 'Party': 'D'},
#  {'State': 'Louisiana', 'Year': 1968, 'County': 'Grant', 'Party': 'D'},
#  {'State': 'Louisiana', 'Year': 1968, 'County': 'Iberia', 'Party': 'D'},
#  {'State': 'Louisiana', 'Year': 1968, 'County': 'Iberville', 'Party': 'D'},
#  {'State': 'Louisiana', 'Year': 1968, 'County': 'Jackson', 'Party': 'D'},
#  {'State': 'Louisiana', 'Year': 1968, 'County': 'Jefferson', 'Party': 'D'},
#  {'State': 'Louisiana',
#   'Year': 1968,
#   'County': 'Jefferson Davis',
#   'Party': 'D'},
#  {'State': 'Louisiana', 'Year': 1968, 'County': 'Lafayette', 'Party': 'D'},
#  {'State': 'Louisiana', 'Year': 1968, 'County': 'Lafourche', 'Party': 'D'},
#  {'State': 'Louisiana', 'Year': 1968, 'County': 'LaSalle', 'Party': 'D'},
#  {'State': 'Louisiana', 'Year': 1968, 'County': 'Lincoln', 'Party': 'D'},
#  {'State': 'Louisiana', 'Year': 1968, 'County': 'Livingston', 'Party': 'D'},
#  {'State': 'Louisiana', 'Year': 1968, 'County': 'Madison', 'Party': 'D'},
#  {'State': 'Louisiana', 'Year': 1968, 'County': 'Morehouse', 'Party': 'D'},
#  {'State': 'Louisiana', 'Year': 1968, 'County': 'Natchitoches', 'Party': 'D'},
#  {'State': 'Louisiana', 'Year': 1968, 'County': 'Orleans', 'Party': 'D'},
#  {'State': 'Louisiana', 'Year': 1968, 'County': 'Ouachita', 'Party': 'D'},
#  {'State': 'Louisiana', 'Year': 1968, 'County': 'Plaquemines', 'Party': 'D'},
#  {'State': 'Louisiana', 'Year': 1968, 'County': 'Pointe Coupee', 'Party': 'D'},
#  {'State': 'Louisiana', 'Year': 1968, 'County': 'Rapides', 'Party': 'D'},
#  {'State': 'Louisiana', 'Year': 1968, 'County': 'Red River', 'Party': 'D'},
#  {'State': 'Louisiana', 'Year': 1968, 'County': 'Richland', 'Party': 'D'},
#  {'State': 'Louisiana', 'Year': 1968, 'County': 'Sabine', 'Party': 'D'},
#  {'State': 'Louisiana', 'Year': 1968, 'County': 'St. Bernard', 'Party': 'D'},
#  {'State': 'Louisiana', 'Year': 1968, 'County': 'St. Charles', 'Party': 'D'},
#  {'State': 'Louisiana', 'Year': 1968, 'County': 'St. Helena', 'Party': 'D'},
#  {'State': 'Louisiana', 'Year': 1968, 'County': 'St. James', 'Party': 'D'},
#  {'State': 'Louisiana',
#   'Year': 1968,
#   'County': 'St. John the Baptist',
#   'Party': 'D'},
#  {'State': 'Louisiana', 'Year': 1968, 'County': 'St. Landry', 'Party': 'D'},
#  {'State': 'Louisiana', 'Year': 1968, 'County': 'St. Martin', 'Party': 'D'},
#  {'State': 'Louisiana', 'Year': 1968, 'County': 'St. Mary', 'Party': 'D'},
#  {'State': 'Louisiana', 'Year': 1968, 'County': 'St. Tammany', 'Party': 'D'},
#  {'State': 'Louisiana', 'Year': 1968, 'County': 'Tangipahoa', 'Party': 'D'},
#  {'State': 'Louisiana', 'Year': 1968, 'County': 'Tensas', 'Party': 'D'},
#  {'State': 'Louisiana', 'Year': 1968, 'County': 'Terrebonne', 'Party': 'D'},
#  {'State': 'Louisiana', 'Year': 1968, 'County': 'Union', 'Party': 'D'},
#  {'State': 'Louisiana', 'Year': 1968, 'County': 'Vermilion', 'Party': 'D'},
#  {'State': 'Louisiana', 'Year': 1968, 'County': 'Vernon', 'Party': 'D'},
#  {'State': 'Louisiana', 'Year': 1968, 'County': 'Washington', 'Party': 'D'},
#  {'State': 'Louisiana', 'Year': 1968, 'County': 'Webster', 'Party': 'D'},
#  {'State': 'Louisiana',
#   'Year': 1968,
#   'County': 'West Baton Rouge',
#   'Party': 'D'},
#  {'State': 'Louisiana', 'Year': 1968, 'County': 'West Carroll', 'Party': 'D'},
#  {'State': 'Louisiana',
#   'Year': 1968,
#   'County': 'West Feliciana',
#   'Party': 'D'},
#  {'State': 'Louisiana', 'Year': 1968, 'County': 'Winn', 'Party': 'D'},
#  {'State': 'Louisiana', 'Year': 1964, 'County': 'Acadia', 'Party': 'D'},
#  {'State': 'Louisiana', 'Year': 1964, 'County': 'Allen', 'Party': 'D'},
#  {'State': 'Louisiana', 'Year': 1964, 'County': 'Ascension', 'Party': 'D'},
#  {'State': 'Louisiana', 'Year': 1964, 'County': 'Assumption', 'Party': 'D'},
#  {'State': 'Louisiana', 'Year': 1964, 'County': 'Avoyelles', 'Party': 'D'},
#  {'State': 'Louisiana', 'Year': 1964, 'County': 'Beauregard', 'Party': 'R'},
#  {'State': 'Louisiana', 'Year': 1964, 'County': 'Bienville', 'Party': 'R'},
#  {'State': 'Louisiana', 'Year': 1964, 'County': 'Bossier', 'Party': 'R'},
#  {'State': 'Louisiana', 'Year': 1964, 'County': 'Caddo', 'Party': 'R'},
#  {'State': 'Louisiana', 'Year': 1964, 'County': 'Calcasieu', 'Party': 'D'},
#  {'State': 'Louisiana', 'Year': 1964, 'County': 'Caldwell', 'Party': 'R'},
#  {'State': 'Louisiana', 'Year': 1964, 'County': 'Cameron', 'Party': 'D'},
#  {'State': 'Louisiana', 'Year': 1964, 'County': 'Catahoula', 'Party': 'R'},
#  {'State': 'Louisiana', 'Year': 1964, 'County': 'Claiborne', 'Party': 'R'},
#  {'State': 'Louisiana', 'Year': 1964, 'County': 'Concordia', 'Party': 'R'},
#  {'State': 'Louisiana', 'Year': 1964, 'County': 'DeSoto', 'Party': 'R'},
#  {'State': 'Louisiana',
#   'Year': 1964,
#   'County': 'East Baton Rouge',
#   'Party': 'R'},
#  {'State': 'Louisiana', 'Year': 1964, 'County': 'East Carroll', 'Party': 'R'},
#  {'State': 'Louisiana',
#   'Year': 1964,
#   'County': 'East Feliciana',
#   'Party': 'R'},
#  {'State': 'Louisiana', 'Year': 1964, 'County': 'Evangeline', 'Party': 'D'},
#  {'State': 'Louisiana', 'Year': 1964, 'County': 'Franklin', 'Party': 'R'},
#  {'State': 'Louisiana', 'Year': 1964, 'County': 'Grant', 'Party': 'R'},
#  {'State': 'Louisiana', 'Year': 1964, 'County': 'Iberia', 'Party': 'R'},
#  {'State': 'Louisiana', 'Year': 1964, 'County': 'Iberville', 'Party': 'D'},
#  {'State': 'Louisiana', 'Year': 1964, 'County': 'Jackson', 'Party': 'R'},
#  {'State': 'Louisiana', 'Year': 1964, 'County': 'Jefferson', 'Party': 'R'},
#  {'State': 'Louisiana',
#   'Year': 1964,
#   'County': 'Jefferson Davis',
#   'Party': 'D'},
#  {'State': 'Louisiana', 'Year': 1964, 'County': 'Lafayette', 'Party': 'D'},
#  {'State': 'Louisiana', 'Year': 1964, 'County': 'Lafourche', 'Party': 'D'},
#  {'State': 'Louisiana', 'Year': 1964, 'County': 'LaSalle', 'Party': 'R'},
#  {'State': 'Louisiana', 'Year': 1964, 'County': 'Lincoln', 'Party': 'R'},
#  {'State': 'Louisiana', 'Year': 1964, 'County': 'Livingston', 'Party': 'R'},
#  {'State': 'Louisiana', 'Year': 1964, 'County': 'Madison', 'Party': 'R'},
#  {'State': 'Louisiana', 'Year': 1964, 'County': 'Morehouse', 'Party': 'R'},
#  {'State': 'Louisiana', 'Year': 1964, 'County': 'Natchitoches', 'Party': 'R'},
#  {'State': 'Louisiana', 'Year': 1964, 'County': 'Orleans', 'Party': 'D'},
#  {'State': 'Louisiana', 'Year': 1964, 'County': 'Ouachita', 'Party': 'R'},
#  {'State': 'Louisiana', 'Year': 1964, 'County': 'Plaquemines', 'Party': 'R'},
#  {'State': 'Louisiana', 'Year': 1964, 'County': 'Pointe Coupee', 'Party': 'R'},
#  {'State': 'Louisiana', 'Year': 1964, 'County': 'Rapides', 'Party': 'R'},
#  {'State': 'Louisiana', 'Year': 1964, 'County': 'Red River', 'Party': 'R'},
#  {'State': 'Louisiana', 'Year': 1964, 'County': 'Richland', 'Party': 'R'},
#  {'State': 'Louisiana', 'Year': 1964, 'County': 'Sabine', 'Party': 'R'},
#  {'State': 'Louisiana', 'Year': 1964, 'County': 'St. Bernard', 'Party': 'R'},
#  {'State': 'Louisiana', 'Year': 1964, 'County': 'St. Charles', 'Party': 'D'},
#  {'State': 'Louisiana', 'Year': 1964, 'County': 'St. Helena', 'Party': 'R'},
#  {'State': 'Louisiana', 'Year': 1964, 'County': 'St. James', 'Party': 'D'},
#  {'State': 'Louisiana',
#   'Year': 1964,
#   'County': 'St. John the Baptist',
#   'Party': 'D'},
#  {'State': 'Louisiana', 'Year': 1964, 'County': 'St. Landry', 'Party': 'D'},
#  {'State': 'Louisiana', 'Year': 1964, 'County': 'St. Martin', 'Party': 'D'},
#  {'State': 'Louisiana', 'Year': 1964, 'County': 'St. Mary', 'Party': 'D'},
#  {'State': 'Louisiana', 'Year': 1964, 'County': 'St. Tammany', 'Party': 'R'},
#  {'State': 'Louisiana', 'Year': 1964, 'County': 'Tangipahoa', 'Party': 'R'},
#  {'State': 'Louisiana', 'Year': 1964, 'County': 'Tensas', 'Party': 'R'},
#  {'State': 'Louisiana', 'Year': 1964, 'County': 'Terrebonne', 'Party': 'D'},
#  {'State': 'Louisiana', 'Year': 1964, 'County': 'Union', 'Party': 'R'},
#  {'State': 'Louisiana', 'Year': 1964, 'County': 'Vermilion', 'Party': 'D'},
#  {'State': 'Louisiana', 'Year': 1964, 'County': 'Vernon', 'Party': 'R'},
#  {'State': 'Louisiana', 'Year': 1964, 'County': 'Washington', 'Party': 'R'},
#  {'State': 'Louisiana', 'Year': 1964, 'County': 'Webster', 'Party': 'R'},
#  {'State': 'Louisiana',
#   'Year': 1964,
#   'County': 'West Baton Rouge',
#   'Party': 'D'},
#  {'State': 'Louisiana', 'Year': 1964, 'County': 'West Carroll', 'Party': 'R'},
#  {'State': 'Louisiana',
#   'Year': 1964,
#   'County': 'West Feliciana',
#   'Party': 'R'},
#  {'State': 'Louisiana', 'Year': 1964, 'County': 'Winn', 'Party': 'R'}]

# %%
# AK_result = []
# for i in range(10):
#     try:
#         year = 2000 - 4*i
#         http = "https://en.wikipedia.org/wiki/" + str(year) + "_United_States_presidential_election_in_Louisiana"
#         f = r.get(http)
#         html_content = f.content
#         soup = BeautifulSoup(html_content, 'html.parser')
#         tables = [table for table in soup.find_all("table")]
#         # states_list = []
#         # for _ in table.find_all("tr")[2:]:
#         #     states_list += [_.find("td").text]
#         # return states_list[:-2]
#         for _ in tables[12].find_all("tr")[2:]:
#             try:
#                 dict = {}
#                 county = _.find("td").text.strip('\n')
#                 party = "R" if _.find("td")['style'].strip('background-color:') == '#FFB6B6' else "D"
                
#                 dict['State'] = 'Louisiana'
#                 dict['Year'] = year
#                 dict['County'] = county
#                 dict['Party'] = party
#                 AK_result += [dict]
#             except Exception as e:
#                 print(e)
#                 pass
#     except Exception as e:
#         print(e)
#         pass
# AK_result

#Alaska has no county-level election results, pass.

# %%
from importlib import reload
import data_processing
reload(data_processing)
data = data_processing.read_data(filename_t1)
data = data + LA_result + WA_result

data = sorted(data, key=lambda d: d['State'])
data = sorted(data, key=lambda d: int(d['Year']))
filename_t2 = datetime.datetime.now().__str__()
data_processing.write_data(filename_t2, data)

# %%
reload(data_processing)
raw_data = read_data(filename_t2)
results = raw_data

# MERGING CAINC DATA WITH BY COUNTY ELECTION RESULTS.
for result in results:
    if int(result['Year']) <= 1972:
        pass
    try:
        state_abbrev = misc.us_state_to_abbrev[result["State"]]
        with open('CAINC30_Economic Profile by County/CAINC30_'+ state_abbrev + '_1969_2023.csv', 'r') as file:
            csv_reader = csv.DictReader(file)
            data = list(csv_reader)[:-5]
        for _ in data:
            del _["Region"]
            del _["TableName"]
            del _["Unit"]
            del _["LineCode"]
        
        
        econ_data = list(filter(lambda d: result["County"] in d["GeoName"], data))
        
        for ed in econ_data:
            year = int(result["Year"])
            label = ed["Description"]
            result[label + "YR-1"] = int(ed[str(year - 1)]) 
            result[label + "YR-2"] = int(ed[str(year - 2)])
            result[label + "YR-3"] = int(ed[str(year - 3)])
            result[label + "YR-4"] = int(ed[str(year - 4)])
            result['GeoFIPS'] = ed['GeoFIPS']

    except Exception as e:
        print(e)
        pass
pd.DataFrame(results)
# Out:
# '1963'
# '1963'
# '1963'
# '1963'
# '1963'
# '1963'
# '1963'
# '1963'
# '1963'
# '1963'
# '1963'
# '1963'
# '1963'
# '1963'
# '1963'
# '1963'
# '1963'
# '1963'
# '1963'
# '1963'
# '1963'
# '1963'
# '1963'
# '1963'
# '1963'
# '1963'
# '1963'
# '1963'
# '1963'
# '1963'
# '1963'
# '1963'
# '1963'
# '1963'
# '1963'
# '1963'
# '1963'
# '1963'
# '1963'
# '1963'
# '1963'
# '1963'
# '1963'
# '1963'
# '1963'
# '1963'
# '1963'
# '1963'
# '1963'
# '1963'
# '1963'
# '1963'
# '1963'
# '1963'
# '1963'
# '1963'
# '1963'
# '1963'
# '1963'
# '1963'
# '1963'
# '1963'
# '1963'
# '1963'
# '1963'
# '1963'
# '1963'
# '1963'
# '1963'
# '1963'
# '1963'
# '1963'
# '1963'
# '1963'
# '1963'
# '1963'
# '1963'
# '1963'
# '1963'
# '1963'
# '1963'
# '1963'
# '1963'
# '1963'
# '1963'
# '1963'
# '1963'
# '1963'
# '1963'
# '1963'
# '1963'
# '1963'
# '1963'
# '1963'
# '1963'
# '1963'
# '1963'
# '1963'
# '1963'
# '1963'
# '1963'
# '1963'
# '1967'
# '1967'
# '1967'
# '1967'
# '1967'
# '1967'
# '1967'
# '1967'
# '1967'
# '1967'
# '1967'
# '1967'
# '1967'
# '1967'
# '1967'
# '1967'
# '1967'
# '1967'
# '1967'
# '1967'
# '1967'
# '1967'
# '1967'
# '1967'
# '1967'
# '1967'
# '1967'
# '1967'
# '1967'
# '1967'
# '1967'
# '1967'
# '1967'
# '1967'
# '1967'
# '1967'
# '1967'
# '1967'
# '1967'
# '1967'
# '1967'
# '1967'
# '1967'
# '1967'
# '1967'
# '1967'
# '1967'
# '1967'
# '1967'
# '1967'
# '1967'
# '1967'
# '1967'
# '1967'
# '1967'
# '1967'
# '1967'
# '1967'
# '1967'
# '1967'
# '1967'
# '1967'
# '1967'
# '1967'
# '1967'
# '1967'
# '1967'
# '1967'
# '1967'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# invalid literal for int() with base 10: '(NA)'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# invalid literal for int() with base 10: '(NA)'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# '1968'
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# invalid literal for int() with base 10: '(NA)'
# invalid literal for int() with base 10: '(NA)'
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# invalid literal for int() with base 10: '(NA)'
# invalid literal for int() with base 10: '(NA)'
# invalid literal for int() with base 10: '(NA)'
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# invalid literal for int() with base 10: '(NA)'
# invalid literal for int() with base 10: '(NA)'
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# invalid literal for int() with base 10: '(NA)'
# invalid literal for int() with base 10: '(NA)'
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# invalid literal for int() with base 10: '(NA)'
# invalid literal for int() with base 10: '(NA)'
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# invalid literal for int() with base 10: '(NA)'
# invalid literal for int() with base 10: '(NA)'
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# invalid literal for int() with base 10: '(NA)'
# invalid literal for int() with base 10: '(NA)'
# invalid literal for int() with base 10: '(NA)'
# invalid literal for int() with base 10: '(NA)'
# invalid literal for int() with base 10: '(NA)'
# invalid literal for int() with base 10: '(NA)'
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 3974: invalid continuation byte
# ...
# 49087                   346482.0                   372505.0
# 49088                    38137.0                    37947.0
# 49089                  2498065.0                  2426043.0
# 49090                  1037855.0                   977450.0
# 49091                   697453.0                   689538.0
#
#          Supplements to wages and salaries YR-1  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
# ...                                         ...
# 49087                                  130848.0
# 49088                                   14290.0
# 49089                                  809424.0
# 49090                                  243051.0
# 49091                                  241514.0
#
#          Supplements to wages and salaries YR-2  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
# ...                                         ...
# 49087                                  131376.0
# 49088                                   15464.0
# 49089                                  814034.0
# 49090                                  239101.0
# 49091                                  256529.0
#
#          Supplements to wages and salaries YR-3  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
# ...                                         ...
# 49087                                  125286.0
# 49088                                   14830.0
# 49089                                  779857.0
# 49090                                  230725.0
# 49091                                  249128.0
#
#          Supplements to wages and salaries YR-4  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
# ...                                         ...
# 49087                                  130514.0
# 49088                                   14647.0
# 49089                                  757857.0
# 49090                                  218498.0
# 49091                                  245963.0
#
#           Employer contributions for employee pension and insurance funds 5/YR-1  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 49087                                            93460.0
# 49088                                            10553.0
# 49089                                           547264.0
# 49090                                           133933.0
# 49091                                           174295.0
#
#           Employer contributions for employee pension and insurance funds 5/YR-2  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 49087                                            95854.0
# 49088                                            11679.0
# 49089                                           567375.0
# 49090                                           135058.0
# 49091                                           193132.0
#
#           Employer contributions for employee pension and insurance funds 5/YR-3  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 49087                                            91226.0
# 49088                                            10879.0
# 49089                                           532113.0
# 49090                                           125086.0
# 49091                                           182171.0
#
#           Employer contributions for employee pension and insurance funds 5/YR-4  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 49087                                            93383.0
# 49088                                            10651.0
# 49089                                           513778.0
# 49090                                           115804.0
# 49091                                           179056.0
#
#           Employer contributions for government social insurance YR-1  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 49087                                            37388.0
# 49088                                             3737.0
# 49089                                           262160.0
# 49090                                           109118.0
# 49091                                            67219.0
#
#           Employer contributions for government social insurance YR-2  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 49087                                            35522.0
# 49088                                             3785.0
# 49089                                           246659.0
# 49090                                           104043.0
# 49091                                            63397.0
#
#           Employer contributions for government social insurance YR-3  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 49087                                            34060.0
# 49088                                             3951.0
# 49089                                           247744.0
# 49090                                           105639.0
# 49091                                            66957.0
#
#           Employer contributions for government social insurance YR-4  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 49087                                            37131.0
# 49088                                             3996.0
# 49089                                           244079.0
# 49090                                           102694.0
# 49091                                            66907.0
#
#          Proprietors' income YR-1    Proprietors' income YR-2  \
# 0                             NaN                         NaN
# 1                             NaN                         NaN
# 2                             NaN                         NaN
# 3                             NaN                         NaN
# 4                             NaN                         NaN
# ...                           ...                         ...
# 49087                     31166.0                     39362.0
# 49088                     20095.0                     24873.0
# 49089                    393102.0                    359741.0
# 49090                    340128.0                    318945.0
# 49091                     96523.0                     84789.0
#
#          Proprietors' income YR-3    Proprietors' income YR-4  \
# 0                             NaN                         NaN
# 1                             NaN                         NaN
# 2                             NaN                         NaN
# 3                             NaN                         NaN
# 4                             NaN                         NaN
# ...                           ...                         ...
# 49087                     50549.0                     37400.0
# 49088                     12254.0                     13491.0
# 49089                    329459.0                    317238.0
# 49090                    327481.0                    270462.0
# 49091                     74943.0                     76419.0
#
#           Farm proprietors' income YR-1     Farm proprietors' income YR-2  \
# 0                                   NaN                               NaN
# 1                                   NaN                               NaN
# 2                                   NaN                               NaN
# 3                                   NaN                               NaN
# 4                                   NaN                               NaN
# ...                                 ...                               ...
# 49087                            4687.0                             659.0
# 49088                            3343.0                            2497.0
# 49089                            -257.0                           -5959.0
# 49090                            -708.0                            -865.0
# 49091                             425.0                            -656.0
#
#           Farm proprietors' income YR-3     Farm proprietors' income YR-4  \
# 0                                   NaN                               NaN
# 1                                   NaN                               NaN
# 2                                   NaN                               NaN
# 3                                   NaN                               NaN
# 4                                   NaN                               NaN
# ...                                 ...                               ...
# 49087                           -1109.0                            -998.0
# 49088                            2737.0                            3516.0
# 49089                           -5154.0                           -2639.0
# 49090                            1896.0                            1388.0
# 49091                           -2398.0                             669.0
#
#           Nonfarm proprietors' income YR-1  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
# ...                                    ...
# 49087                              26479.0
# 49088                              16752.0
# 49089                             393359.0
# 49090                             340836.0
# 49091                              96098.0
#
#           Nonfarm proprietors' income YR-2  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
# ...                                    ...
# 49087                              38703.0
# 49088                              22376.0
# 49089                             365700.0
# 49090                             319810.0
# 49091                              85445.0
#
#           Nonfarm proprietors' income YR-3  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
# ...                                    ...
# 49087                              51658.0
# 49088                               9517.0
# 49089                             334613.0
# 49090                             325585.0
# 49091                              77341.0
#
#           Nonfarm proprietors' income YR-4
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
# ...                                    ...
# 49087                              38398.0
# 49088                               9975.0
# 49089                             319877.0
# 49090                             269074.0
# 49091                              75750.0
#
# [49092 rows x 97 columns]

# %%
filename_t3 = datetime.datetime.now().__str__()
pd.DataFrame(results).to_csv(filename_t3)

# %%
for result in results:
    state_abbrev = misc.us_state_to_abbrev[result["State"]]
    try:
        with open('CAINC1_Annual Personal Income by County/CAINC1_'+ state_abbrev + '_1969_2023.csv', 'r') as file:
            csv_reader = csv.DictReader(file)
            data = list(csv_reader)[:-5]
        for _ in data:
            del _["Region"]
            del _["TableName"]
            del _["Unit"]
            del _["LineCode"]
        
        
        econ_data = list(filter(lambda d: result["County"] in d["GeoName"], data))
        
        for ed in econ_data:
            year = int(result["Year"])
            label = ed["Description"]
            result[label + "YR-1"] = int(ed[str(year - 1)]) 
            result[label + "YR-2"] = int(ed[str(year - 2)])
            result[label + "YR-3"] = int(ed[str(year - 3)])
            result[label + "YR-4"] = int(ed[str(year - 4)])
    except Exception as e:
        print(e)
        pass

filename_t4 = datetime.datetime.now().__str__()
pd.DataFrame(results).to_csv(filename_t4)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 for result in results:
#       2     state_abbrev = misc.us_state_to_abbrev[result["State"]]
#       3     try:
#
# NameError: name 'results' is not defined

# %%
# REMOVE ROWS WITH TOO MANY MISSING DATA
df = pd.DataFrame(results)
columns = df.columns
data = list(filter(lambda x: len(x.values()) == len(columns), results))

# %%
# ADJUST FOR INFLATION USING PANDAS
df = pd.DataFrame(data)
# remove population columns
columns = df.columns
populations = [df['Population (persons) 1/YR-1'],
            df['Population (persons) 1/YR-2'],
            df['Population (persons) 1/YR-3'], 
            df['Population (persons) 1/YR-4']]
fips = df['GeoFIPS']4
df.drop(columns = "Population (persons) 1/YR-1", inplace=True)
df.drop(columns = "Population (persons) 1/YR-2", inplace=True)
df.drop(columns = "Population (persons) 1/YR-3", inplace=True)
df.drop(columns = "Population (persons) 1/YR-4", inplace=True)
df.drop(columns = " Population (persons) 3/YR-1", inplace=True)
df.drop(columns = " Population (persons) 3/YR-2", inplace=True)
df.drop(columns = " Population (persons) 3/YR-3", inplace=True)
df.drop(columns = " Population (persons) 3/YR-4", inplace=True)
df.drop(columns = "GeoFIPS", inplace=True)
#adjust for inflation
for i in df.index:
    try:
        year = int(df.iloc[i,1])
        df.iloc[i, 4:] = df.iloc[i, 4:].map(lambda x: int(x) * misc.cpi_dict[year])
    except Exception as e:
        print(e)
        pass

#add population columns back
df["Population YR-1"] = populations[0]
df["Population YR-2"] = populations[1]
df["Population YR-3"] = populations[2]
df["Population YR-4"] = populations[3]
df['GeoFIPS'] = fips

# NORMALIZE DATA
for column in df.columns:
    try:
        if (column != "Year") and (column!='GeoFIPS'):
            df[column] = df[column].map(lambda x: int(x))
            x_max = max(list(df[column]))
            x_min = min(list(df[column]))
            df[column] = df[column].map(lambda x: (x - x_min)/(x_max - x_min))
    except Exception as e:
        print(e)
filename = datetime.datetime.now().__str__()
df.to_csv(filename)
# Out:
# /var/folders/lm/hbk4x935307fwygp1qdwrtq00000gn/T/ipykernel_15596/2463996924.py:23: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '705221.8011599297' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.iloc[i, 4:] = df.iloc[i, 4:].map(lambda x: int(x) * misc.cpi_dict[year])
# /var/folders/lm/hbk4x935307fwygp1qdwrtq00000gn/T/ipykernel_15596/2463996924.py:23: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '665407.0494903339' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.iloc[i, 4:] = df.iloc[i, 4:].map(lambda x: int(x) * misc.cpi_dict[year])
# /var/folders/lm/hbk4x935307fwygp1qdwrtq00000gn/T/ipykernel_15596/2463996924.py:23: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '615573.0106151142' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.iloc[i, 4:] = df.iloc[i, 4:].map(lambda x: int(x) * misc.cpi_dict[year])
# /var/folders/lm/hbk4x935307fwygp1qdwrtq00000gn/T/ipykernel_15596/2463996924.py:23: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '536366.5557469244' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.iloc[i, 4:] = df.iloc[i, 4:].map(lambda x: int(x) * misc.cpi_dict[year])
# /var/folders/lm/hbk4x935307fwygp1qdwrtq00000gn/T/ipykernel_15596/2463996924.py:23: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '522095.363655536' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.iloc[i, 4:] = df.iloc[i, 4:].map(lambda x: int(x) * misc.cpi_dict[year])
# /var/folders/lm/hbk4x935307fwygp1qdwrtq00000gn/T/ipykernel_15596/2463996924.py:23: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '514550.10674868186' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.iloc[i, 4:] = df.iloc[i, 4:].map(lambda x: int(x) * misc.cpi_dict[year])
# /var/folders/lm/hbk4x935307fwygp1qdwrtq00000gn/T/ipykernel_15596/2463996924.py:23: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '488556.7234797891' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.iloc[i, 4:] = df.iloc[i, 4:].map(lambda x: int(x) * misc.cpi_dict[year])
# /var/folders/lm/hbk4x935307fwygp1qdwrtq00000gn/T/ipykernel_15596/2463996924.py:23: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '425324.3646748682' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.iloc[i, 4:] = df.iloc[i, 4:].map(lambda x: int(x) * misc.cpi_dict[year])
# /var/folders/lm/hbk4x935307fwygp1qdwrtq00000gn/T/ipykernel_15596/2463996924.py:23: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '90071.83901581723' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.iloc[i, 4:] = df.iloc[i, 4:].map(lambda x: int(x) * misc.cpi_dict[year])
# /var/folders/lm/hbk4x935307fwygp1qdwrtq00000gn/T/ipykernel_15596/2463996924.py:23: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '66606.03648506152' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.iloc[i, 4:] = df.iloc[i, 4:].map(lambda x: int(x) * misc.cpi_dict[year])
# /var/folders/lm/hbk4x935307fwygp1qdwrtq00000gn/T/ipykernel_15596/2463996924.py:23: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '53261.26699472759' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.iloc[i, 4:] = df.iloc[i, 4:].map(lambda x: int(x) * misc.cpi_dict[year])
# /var/folders/lm/hbk4x935307fwygp1qdwrtq00000gn/T/ipykernel_15596/2463996924.py:23: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '44537.90042179262' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.iloc[i, 4:] = df.iloc[i, 4:].map(lambda x: int(x) * misc.cpi_dict[year])
# /var/folders/lm/hbk4x935307fwygp1qdwrtq00000gn/T/ipykernel_15596/2463996924.py:23: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '15133.354165202109' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.iloc[i, 4:] = df.iloc[i, 4:].map(lambda x: int(x) * misc.cpi_dict[year])
# /var/folders/lm/hbk4x935307fwygp1qdwrtq00000gn/T/ipykernel_15596/2463996924.py:23: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '10453.045764499122' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.iloc[i, 4:] = df.iloc[i, 4:].map(lambda x: int(x) * misc.cpi_dict[year])
# /var/folders/lm/hbk4x935307fwygp1qdwrtq00000gn/T/ipykernel_15596/2463996924.py:23: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '6474.248119507908' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.iloc[i, 4:] = df.iloc[i, 4:].map(lambda x: int(x) * misc.cpi_dict[year])
# /var/folders/lm/hbk4x935307fwygp1qdwrtq00000gn/T/ipykernel_15596/2463996924.py:23: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '5890.548330404218' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.iloc[i, 4:] = df.iloc[i, 4:].map(lambda x: int(x) * misc.cpi_dict[year])
# /var/folders/lm/hbk4x935307fwygp1qdwrtq00000gn/T/ipykernel_15596/2463996924.py:23: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '4782.054235500878' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.iloc[i, 4:] = df.iloc[i, 4:].map(lambda x: int(x) * misc.cpi_dict[year])
# /var/folders/lm/hbk4x935307fwygp1qdwrtq00000gn/T/ipykernel_15596/2463996924.py:23: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1253.0802811950791' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.iloc[i, 4:] = df.iloc[i, 4:].map(lambda x: int(x) * misc.cpi_dict[year])
# /var/folders/lm/hbk4x935307fwygp1qdwrtq00000gn/T/ipykernel_15596/2463996924.py:23: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '701.510755711775' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.iloc[i, 4:] = df.iloc[i, 4:].map(lambda x: int(x) * misc.cpi_dict[year])
# /var/folders/lm/hbk4x935307fwygp1qdwrtq00000gn/T/ipykernel_15596/2463996924.py:23: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '921.0675571177504' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.iloc[i, 4:] = df.iloc[i, 4:].map(lambda x: int(x) * misc.cpi_dict[year])
# /var/folders/lm/hbk4x935307fwygp1qdwrtq00000gn/T/ipykernel_15596/2463996924.py:23: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '70156.43061511424' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.iloc[i, 4:] = df.iloc[i, 4:].map(lambda x: int(x) * misc.cpi_dict[year])
# /var/folders/lm/hbk4x935307fwygp1qdwrtq00000gn/T/ipykernel_15596/2463996924.py:23: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '54899.91043936731' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.iloc[i, 4:] = df.iloc[i, 4:].map(lambda x: int(x) * misc.cpi_dict[year])
# /var/folders/lm/hbk4x935307fwygp1qdwrtq00000gn/T/ipykernel_15596/2463996924.py:23: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '46085.50811950791' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.iloc[i, 4:] = df.iloc[i, 4:].map(lambda x: int(x) * misc.cpi_dict[year])
# /var/folders/lm/hbk4x935307fwygp1qdwrtq00000gn/T/ipykernel_15596/2463996924.py:23: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '37726.28453427065' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.iloc[i, 4:] = df.iloc[i, 4:].map(lambda x: int(x) * misc.cpi_dict[year])
# /var/folders/lm/hbk4x935307fwygp1qdwrtq00000gn/T/ipykernel_15596/2463996924.py:23: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '93054.59848857645' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.iloc[i, 4:] = df.iloc[i, 4:].map(lambda x: int(x) * misc.cpi_dict[year])
# /var/folders/lm/hbk4x935307fwygp1qdwrtq00000gn/T/ipykernel_15596/2463996924.py:23: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '84250.9062565905' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.iloc[i, 4:] = df.iloc[i, 4:].map(lambda x: int(x) * misc.cpi_dict[year])
# /var/folders/lm/hbk4x935307fwygp1qdwrtq00000gn/T/ipykernel_15596/2463996924.py:23: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '73755.02014059754' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.iloc[i, 4:] = df.iloc[i, 4:].map(lambda x: int(x) * misc.cpi_dict[year])
# /var/folders/lm/hbk4x935307fwygp1qdwrtq00000gn/T/ipykernel_15596/2463996924.py:23: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '66504.29065026362' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.iloc[i, 4:] = df.iloc[i, 4:].map(lambda x: int(x) * misc.cpi_dict[year])
# /var/folders/lm/hbk4x935307fwygp1qdwrtq00000gn/T/ipykernel_15596/2463996924.py:23: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '23728.199683655537' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.iloc[i, 4:] = df.iloc[i, 4:].map(lambda x: int(x) * misc.cpi_dict[year])
# /var/folders/lm/hbk4x935307fwygp1qdwrtq00000gn/T/ipykernel_15596/2463996924.py:23: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '22737.516555360282' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.iloc[i, 4:] = df.iloc[i, 4:].map(lambda x: int(x) * misc.cpi_dict[year])
# /var/folders/lm/hbk4x935307fwygp1qdwrtq00000gn/T/ipykernel_15596/2463996924.py:23: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '21629.02246045694' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.iloc[i, 4:] = df.iloc[i, 4:].map(lambda x: int(x) * misc.cpi_dict[year])
# /var/folders/lm/hbk4x935307fwygp1qdwrtq00000gn/T/ipykernel_15596/2463996924.py:23: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '19744.046994727592' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.iloc[i, 4:] = df.iloc[i, 4:].map(lambda x: int(x) * misc.cpi_dict[year])
# /var/folders/lm/hbk4x935307fwygp1qdwrtq00000gn/T/ipykernel_15596/2463996924.py:23: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '17569.899156414762' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.iloc[i, 4:] = df.iloc[i, 4:].map(lambda x: int(x) * misc.cpi_dict[year])
# /var/folders/lm/hbk4x935307fwygp1qdwrtq00000gn/T/ipykernel_15596/2463996924.py:23: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '17580.609244288225' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.iloc[i, 4:] = df.iloc[i, 4:].map(lambda x: int(x) * misc.cpi_dict[year])
# /var/folders/lm/hbk4x935307fwygp1qdwrtq00000gn/T/ipykernel_15596/2463996924.py:23: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '17162.9158172232' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.iloc[i, 4:] = df.iloc[i, 4:].map(lambda x: int(x) * misc.cpi_dict[year])
# /var/folders/lm/hbk4x935307fwygp1qdwrtq00000gn/T/ipykernel_15596/2463996924.py:23: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '15658.148471001758' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.iloc[i, 4:] = df.iloc[i, 4:].map(lambda x: int(x) * misc.cpi_dict[year])
# /var/folders/lm/hbk4x935307fwygp1qdwrtq00000gn/T/ipykernel_15596/2463996924.py:23: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3030.954868189807' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.iloc[i, 4:] = df.iloc[i, 4:].map(lambda x: int(x) * misc.cpi_dict[year])
# /var/folders/lm/hbk4x935307fwygp1qdwrtq00000gn/T/ipykernel_15596/2463996924.py:23: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '2275.8936731107206' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.iloc[i, 4:] = df.iloc[i, 4:].map(lambda x: int(x) * misc.cpi_dict[year])
# /var/folders/lm/hbk4x935307fwygp1qdwrtq00000gn/T/ipykernel_15596/2463996924.py:23: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1868.9103339191563' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.iloc[i, 4:] = df.iloc[i, 4:].map(lambda x: int(x) * misc.cpi_dict[year])
# /var/folders/lm/hbk4x935307fwygp1qdwrtq00000gn/T/ipykernel_15596/2463996924.py:23: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1638.6434446397188' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.iloc[i, 4:] = df.iloc[i, 4:].map(lambda x: int(x) * misc.cpi_dict[year])
# /var/folders/lm/hbk4x935307fwygp1qdwrtq00000gn/T/ipykernel_15596/2463996924.py:23: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '508.72917398945515' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.iloc[i, 4:] = df.iloc[i, 4:].map(lambda x: int(x) * misc.cpi_dict[year])
# /var/folders/lm/hbk4x935307fwygp1qdwrtq00000gn/T/ipykernel_15596/2463996924.py:23: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '358.78794376098415' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.iloc[i, 4:] = df.iloc[i, 4:].map(lambda x: int(x) * misc.cpi_dict[year])
# /var/folders/lm/hbk4x935307fwygp1qdwrtq00000gn/T/ipykernel_15596/2463996924.py:23: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '224.9118453427065' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.iloc[i, 4:] = df.iloc[i, 4:].map(lambda x: int(x) * misc.cpi_dict[year])
# /var/folders/lm/hbk4x935307fwygp1qdwrtq00000gn/T/ipykernel_15596/2463996924.py:23: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '214.20175746924428' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.iloc[i, 4:] = df.iloc[i, 4:].map(lambda x: int(x) * misc.cpi_dict[year])
# /var/folders/lm/hbk4x935307fwygp1qdwrtq00000gn/T/ipykernel_15596/2463996924.py:23: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '160.6513181019332' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.iloc[i, 4:] = df.iloc[i, 4:].map(lambda x: int(x) * misc.cpi_dict[year])
# /var/folders/lm/hbk4x935307fwygp1qdwrtq00000gn/T/ipykernel_15596/2463996924.py:23: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '42.84035149384886' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.iloc[i, 4:] = df.iloc[i, 4:].map(lambda x: int(x) * misc.cpi_dict[year])
# /var/folders/lm/hbk4x935307fwygp1qdwrtq00000gn/T/ipykernel_15596/2463996924.py:23: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '26.775219683655536' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.iloc[i, 4:] = df.iloc[i, 4:].map(lambda x: int(x) * misc.cpi_dict[year])
# /var/folders/lm/hbk4x935307fwygp1qdwrtq00000gn/T/ipykernel_15596/2463996924.py:23: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '32.13026362038664' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.iloc[i, 4:] = df.iloc[i, 4:].map(lambda x: int(x) * misc.cpi_dict[year])
# /var/folders/lm/hbk4x935307fwygp1qdwrtq00000gn/T/ipykernel_15596/2463996924.py:23: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '2361.5743760984183' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.iloc[i, 4:] = df.iloc[i, 4:].map(lambda x: int(x) * misc.cpi_dict[year])
# /var/folders/lm/hbk4x935307fwygp1qdwrtq00000gn/T/ipykernel_15596/2463996924.py:23: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1874.2653778558874' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.iloc[i, 4:] = df.iloc[i, 4:].map(lambda x: int(x) * misc.cpi_dict[year])
# /var/folders/lm/hbk4x935307fwygp1qdwrtq00000gn/T/ipykernel_15596/2463996924.py:23: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1617.2232688927943' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.iloc[i, 4:] = df.iloc[i, 4:].map(lambda x: int(x) * misc.cpi_dict[year])
# /var/folders/lm/hbk4x935307fwygp1qdwrtq00000gn/T/ipykernel_15596/2463996924.py:23: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1386.9563796133568' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.iloc[i, 4:] = df.iloc[i, 4:].map(lambda x: int(x) * misc.cpi_dict[year])
# /var/folders/lm/hbk4x935307fwygp1qdwrtq00000gn/T/ipykernel_15596/2463996924.py:23: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3132.7007029876977' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.iloc[i, 4:] = df.iloc[i, 4:].map(lambda x: int(x) * misc.cpi_dict[year])
# /var/folders/lm/hbk4x935307fwygp1qdwrtq00000gn/T/ipykernel_15596/2463996924.py:23: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '2881.0136379613355' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.iloc[i, 4:] = df.iloc[i, 4:].map(lambda x: int(x) * misc.cpi_dict[year])
# /var/folders/lm/hbk4x935307fwygp1qdwrtq00000gn/T/ipykernel_15596/2463996924.py:23: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '2591.841265377856' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.iloc[i, 4:] = df.iloc[i, 4:].map(lambda x: int(x) * misc.cpi_dict[year])
# /var/folders/lm/hbk4x935307fwygp1qdwrtq00000gn/T/ipykernel_15596/2463996924.py:23: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '2447.255079086116' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.iloc[i, 4:] = df.iloc[i, 4:].map(lambda x: int(x) * misc.cpi_dict[year])
# /var/folders/lm/hbk4x935307fwygp1qdwrtq00000gn/T/ipykernel_15596/2463996924.py:23: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '325110.0724428822' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.iloc[i, 4:] = df.iloc[i, 4:].map(lambda x: int(x) * misc.cpi_dict[year])
# /var/folders/lm/hbk4x935307fwygp1qdwrtq00000gn/T/ipykernel_15596/2463996924.py:23: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '328135.67226713535' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.iloc[i, 4:] = df.iloc[i, 4:].map(lambda x: int(x) * misc.cpi_dict[year])
# /var/folders/lm/hbk4x935307fwygp1qdwrtq00000gn/T/ipykernel_15596/2463996924.py:23: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '324253.26541300525' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.iloc[i, 4:] = df.iloc[i, 4:].map(lambda x: int(x) * misc.cpi_dict[year])
# /var/folders/lm/hbk4x935307fwygp1qdwrtq00000gn/T/ipykernel_15596/2463996924.py:23: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '265893.99659050966' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.iloc[i, 4:] = df.iloc[i, 4:].map(lambda x: int(x) * misc.cpi_dict[year])
# /var/folders/lm/hbk4x935307fwygp1qdwrtq00000gn/T/ipykernel_15596/2463996924.py:23: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '231198.6669244288' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.iloc[i, 4:] = df.iloc[i, 4:].map(lambda x: int(x) * misc.cpi_dict[year])
# /var/folders/lm/hbk4x935307fwygp1qdwrtq00000gn/T/ipykernel_15596/2463996924.py:23: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '230229.4039718805' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.iloc[i, 4:] = df.iloc[i, 4:].map(lambda x: int(x) * misc.cpi_dict[year])
# /var/folders/lm/hbk4x935307fwygp1qdwrtq00000gn/T/ipykernel_15596/2463996924.py:23: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '212311.4269595782' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.iloc[i, 4:] = df.iloc[i, 4:].map(lambda x: int(x) * misc.cpi_dict[year])
# /var/folders/lm/hbk4x935307fwygp1qdwrtq00000gn/T/ipykernel_15596/2463996924.py:23: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '168673.17391915643' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.iloc[i, 4:] = df.iloc[i, 4:].map(lambda x: int(x) * misc.cpi_dict[year])
# /var/folders/lm/hbk4x935307fwygp1qdwrtq00000gn/T/ipykernel_15596/2463996924.py:23: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '34138.405096660805' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.iloc[i, 4:] = df.iloc[i, 4:].map(lambda x: int(x) * misc.cpi_dict[year])
# /var/folders/lm/hbk4x935307fwygp1qdwrtq00000gn/T/ipykernel_15596/2463996924.py:23: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '30668.33662565905' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.iloc[i, 4:] = df.iloc[i, 4:].map(lambda x: int(x) * misc.cpi_dict[year])
# /var/folders/lm/hbk4x935307fwygp1qdwrtq00000gn/T/ipykernel_15596/2463996924.py:23: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '27374.98460456942' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.iloc[i, 4:] = df.iloc[i, 4:].map(lambda x: int(x) * misc.cpi_dict[year])
# /var/folders/lm/hbk4x935307fwygp1qdwrtq00000gn/T/ipykernel_15596/2463996924.py:23: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '21618.31237258348' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.iloc[i, 4:] = df.iloc[i, 4:].map(lambda x: int(x) * misc.cpi_dict[year])
# /var/folders/lm/hbk4x935307fwygp1qdwrtq00000gn/T/ipykernel_15596/2463996924.py:23: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '19856.502917398946' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.iloc[i, 4:] = df.iloc[i, 4:].map(lambda x: int(x) * misc.cpi_dict[year])
# /var/folders/lm/hbk4x935307fwygp1qdwrtq00000gn/T/ipykernel_15596/2463996924.py:23: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '16627.41142355009' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.iloc[i, 4:] = df.iloc[i, 4:].map(lambda x: int(x) * misc.cpi_dict[year])
# /var/folders/lm/hbk4x935307fwygp1qdwrtq00000gn/T/ipykernel_15596/2463996924.py:23: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '14774.566221441124' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.iloc[i, 4:] = df.iloc[i, 4:].map(lambda x: int(x) * misc.cpi_dict[year])
# /var/folders/lm/hbk4x935307fwygp1qdwrtq00000gn/T/ipykernel_15596/2463996924.py:23: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '12980.626502636203' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.iloc[i, 4:] = df.iloc[i, 4:].map(lambda x: int(x) * misc.cpi_dict[year])
# /var/folders/lm/hbk4x935307fwygp1qdwrtq00000gn/T/ipykernel_15596/2463996924.py:23: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '14281.902179261862' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.iloc[i, 4:] = df.iloc[i, 4:].map(lambda x: int(x) * misc.cpi_dict[year])
# /var/folders/lm/hbk4x935307fwygp1qdwrtq00000gn/T/ipykernel_15596/2463996924.py:23: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '14040.925202108963' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.iloc[i, 4:] = df.iloc[i, 4:].map(lambda x: int(x) * misc.cpi_dict[year])
# /var/folders/lm/hbk4x935307fwygp1qdwrtq00000gn/T/ipykernel_15596/2463996924.py:23: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '12600.418383128295' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.iloc[i, 4:] = df.iloc[i, 4:].map(lambda x: int(x) * misc.cpi_dict[year])
# /var/folders/lm/hbk4x935307fwygp1qdwrtq00000gn/T/ipykernel_15596/2463996924.py:23: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '8637.685869947276' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.iloc[i, 4:] = df.iloc[i, 4:].map(lambda x: int(x) * misc.cpi_dict[year])
# /var/folders/lm/hbk4x935307fwygp1qdwrtq00000gn/T/ipykernel_15596/2463996924.py:23: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '59773.00042179262' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.iloc[i, 4:] = df.iloc[i, 4:].map(lambda x: int(x) * misc.cpi_dict[year])
# /var/folders/lm/hbk4x935307fwygp1qdwrtq00000gn/T/ipykernel_15596/2463996924.py:23: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '67237.93166959578' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.iloc[i, 4:] = df.iloc[i, 4:].map(lambda x: int(x) * misc.cpi_dict[year])
# /var/folders/lm/hbk4x935307fwygp1qdwrtq00000gn/T/ipykernel_15596/2463996924.py:23: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '84566.85384885765' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.iloc[i, 4:] = df.iloc[i, 4:].map(lambda x: int(x) * misc.cpi_dict[year])
# /var/folders/lm/hbk4x935307fwygp1qdwrtq00000gn/T/ipykernel_15596/2463996924.py:23: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '75602.51029876978' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.iloc[i, 4:] = df.iloc[i, 4:].map(lambda x: int(x) * misc.cpi_dict[year])
# /var/folders/lm/hbk4x935307fwygp1qdwrtq00000gn/T/ipykernel_15596/2463996924.py:23: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '11363.40323374341' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.iloc[i, 4:] = df.iloc[i, 4:].map(lambda x: int(x) * misc.cpi_dict[year])
# /var/folders/lm/hbk4x935307fwygp1qdwrtq00000gn/T/ipykernel_15596/2463996924.py:23: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '18544.517152899825' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.iloc[i, 4:] = df.iloc[i, 4:].map(lambda x: int(x) * misc.cpi_dict[year])
# /var/folders/lm/hbk4x935307fwygp1qdwrtq00000gn/T/ipykernel_15596/2463996924.py:23: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '33244.112759226715' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.iloc[i, 4:] = df.iloc[i, 4:].map(lambda x: int(x) * misc.cpi_dict[year])
# /var/folders/lm/hbk4x935307fwygp1qdwrtq00000gn/T/ipykernel_15596/2463996924.py:23: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '28156.82101933216' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.iloc[i, 4:] = df.iloc[i, 4:].map(lambda x: int(x) * misc.cpi_dict[year])
# /var/folders/lm/hbk4x935307fwygp1qdwrtq00000gn/T/ipykernel_15596/2463996924.py:23: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '48409.59718804921' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.iloc[i, 4:] = df.iloc[i, 4:].map(lambda x: int(x) * misc.cpi_dict[year])
# /var/folders/lm/hbk4x935307fwygp1qdwrtq00000gn/T/ipykernel_15596/2463996924.py:23: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '48693.41451669596' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.iloc[i, 4:] = df.iloc[i, 4:].map(lambda x: int(x) * misc.cpi_dict[year])
# /var/folders/lm/hbk4x935307fwygp1qdwrtq00000gn/T/ipykernel_15596/2463996924.py:23: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '51322.74108963093' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.iloc[i, 4:] = df.iloc[i, 4:].map(lambda x: int(x) * misc.cpi_dict[year])
# /var/folders/lm/hbk4x935307fwygp1qdwrtq00000gn/T/ipykernel_15596/2463996924.py:23: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '47445.68927943761' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.iloc[i, 4:] = df.iloc[i, 4:].map(lambda x: int(x) * misc.cpi_dict[year])
# /var/folders/lm/hbk4x935307fwygp1qdwrtq00000gn/T/ipykernel_15596/2463996924.py:23: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '23728.199683655537' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.iloc[i, 4:] = df.iloc[i, 4:].map(lambda x: int(x) * misc.cpi_dict[year])
# /var/folders/lm/hbk4x935307fwygp1qdwrtq00000gn/T/ipykernel_15596/2463996924.py:23: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '22737.516555360282' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.iloc[i, 4:] = df.iloc[i, 4:].map(lambda x: int(x) * misc.cpi_dict[year])
# /var/folders/lm/hbk4x935307fwygp1qdwrtq00000gn/T/ipykernel_15596/2463996924.py:23: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '21629.02246045694' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.iloc[i, 4:] = df.iloc[i, 4:].map(lambda x: int(x) * misc.cpi_dict[year])
# /var/folders/lm/hbk4x935307fwygp1qdwrtq00000gn/T/ipykernel_15596/2463996924.py:23: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '19744.046994727592' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.iloc[i, 4:] = df.iloc[i, 4:].map(lambda x: int(x) * misc.cpi_dict[year])
# invalid literal for int() with base 10: 'Alabama'
# invalid literal for int() with base 10: 'Autauga'
# invalid literal for int() with base 10: 'D'

# %%
df_2024 = df
df_2024
# Out:
#                   State      County  Year  \
# 0     0.000000  Alabama     Autauga  2024
# 1     0.000326  Alabama     Baldwin  2024
# 2     0.000651  Alabama     Barbour  2024
# 3     0.000977  Alabama        Bibb  2024
# 4     0.001303  Alabama      Blount  2024
# ...        ...      ...         ...   ...
# 3066  0.998697  Wyoming  Sweetwater  2024
# 3067  0.999023  Wyoming       Teton  2024
# 3068  0.999349  Wyoming       Uinta  2024
# 3069  0.999674  Wyoming    Washakie  2024
# 3070  1.000000  Wyoming      Weston  2024
#
#       Personal income (thousands of dollars) YR-1  \
# 0                                        0.004220
# 1                                        0.020414
# 2                                        0.001337
# 3                                        0.001139
# 4                                        0.003546
# ...                                           ...
# 3066                                     0.003483
# 3067                                     0.014472
# 3068                                     0.001340
# 3069                                     0.000573
# 3070                                     0.000477
#
#       Personal income (thousands of dollars) YR-2  \
# 0                                        0.004105
# 1                                        0.019639
# 2                                        0.001391
# 3                                        0.001151
# 4                                        0.003617
# ...                                           ...
# 3066                                     0.003430
# 3067                                     0.013481
# 3068                                     0.001320
# 3069                                     0.000574
# 3070                                     0.000474
#
#       Personal income (thousands of dollars) YR-3  \
# 0                                        0.004036
# 1                                        0.018722
# 2                                        0.001386
# 3                                        0.001151
# 4                                        0.003519
# ...                                           ...
# 3066                                     0.003239
# 3067                                     0.011580
# 3068                                     0.001274
# 3069                                     0.000619
# 3070                                     0.000463
#
#       Personal income (thousands of dollars) YR-4  \
# 0                                        0.003903
# 1                                        0.017484
# 2                                        0.001354
# 3                                        0.001129
# 4                                        0.003280
# ...                                           ...
# 3066                                     0.003384
# 3067                                     0.010277
# 3068                                     0.001261
# 3069                                     0.000608
# 3070                                     0.000471
#
#        Net earnings by place of residence YR-1  \
# 0                                     0.004424
# 1                                     0.018805
# 2                                     0.001025
# 3                                     0.001086
# 4                                     0.003716
# ...                                        ...
# 3066                                  0.003950
# 3067                                  0.005319
# 3068                                  0.001293
# 3069                                  0.000483
# 3070                                  0.000419
#
#        Net earnings by place of residence YR-2  \
# 0                                     0.004193
# 1                                     0.017662
# 2                                     0.001089
# 3                                     0.001080
# 4                                     0.003740
# ...                                        ...
# 3066                                  0.003844
# 3067                                  0.005025
# 3068                                  0.001257
# 3069                                  0.000492
# 3070                                  0.000417
#
#        Net earnings by place of residence YR-3  \
# 0                                     0.004092
# 1                                     0.017078
# 2                                     0.001074
# 3                                     0.001058
# 4                                     0.003514
# ...                                        ...
# 3066                                  0.003714
# 3067                                  0.005216
# 3068                                  0.001252
# 3069                                  0.000523
# 3070                                  0.000415
#
#        Net earnings by place of residence YR-4  \
# 0                                     0.004019
# 1                                     0.016221
# 2                                     0.001086
# 3                                     0.001057
# 4                                     0.003269
# ...                                        ...
# 3066                                  0.004012
# 3067                                  0.004208
# 3068                                  0.001298
# 3069                                  0.000502
# 3070                                  0.000425
#
#        Personal current transfer receipts YR-1  \
# 0                                     0.004984
# 1                                     0.023256
# 2                                     0.002675
# 3                                     0.001908
# 4                                     0.004744
# ...                                        ...
# 3066                                  0.002981
# 3067                                  0.001505
# 3068                                  0.001668
# 3069                                  0.000766
# 3070                                  0.000658
#
#        Personal current transfer receipts YR-2  \
# 0                                     0.004989
# 1                                     0.022686
# 2                                     0.002694
# 3                                     0.001944
# 4                                     0.004834
# ...                                        ...
# 3066                                  0.003026
# 3067                                  0.001471
# 3068                                  0.001678
# 3069                                  0.000749
# 3070                                  0.000648
#
#        Personal current transfer receipts YR-3  \
# 0                                     0.004564
# 1                                     0.019950
# 2                                     0.002415
# 3                                     0.001828
# 4                                     0.004486
# ...                                        ...
# 3066                                  0.002700
# 3067                                  0.001356
# 3068                                  0.001477
# 3069                                  0.000655
# 3070                                  0.000570
#
#        Personal current transfer receipts YR-4  \
# 0                                     0.004199
# 1                                     0.018437
# 2                                     0.002232
# 3                                     0.001736
# 4                                     0.004124
# ...                                        ...
# 3066                                  0.002608
# 3067                                  0.001437
# 3068                                  0.001335
# 3069                                  0.000634
# 3070                                  0.000547
#
#         Income maintenance benefits 1/YR-1  \
# 0                                 0.002966
# 1                                 0.008528
# 2                                 0.002302
# 3                                 0.001317
# 4                                 0.002647
# ...                                    ...
# 3066                              0.001228
# 3067                              0.000155
# 3068                              0.000689
# 3069                              0.000238
# 3070                              0.000175
#
#         Income maintenance benefits 1/YR-2  \
# 0                                 0.004424
# 1                                 0.013547
# 2                                 0.002717
# 3                                 0.001786
# 4                                 0.004100
# ...                                    ...
# 3066                              0.002217
# 3067                              0.000541
# 3068                              0.001223
# 3069                              0.000384
# 3070                              0.000325
#
#         Income maintenance benefits 1/YR-3  \
# 0                                 0.003619
# 1                                 0.010830
# 2                                 0.002554
# 3                                 0.001593
# 4                                 0.003327
# ...                                    ...
# 3066                              0.001436
# 3067                              0.000269
# 3068                              0.000896
# 3069                              0.000287
# 3070                              0.000208
#
#         Income maintenance benefits 1/YR-4  \
# 0                                 0.003216
# 1                                 0.009647
# 2                                 0.002398
# 3                                 0.001424
# 4                                 0.002734
# ...                                    ...
# 3066                              0.001068
# 3067                              0.000166
# 3068                              0.000642
# 3069                              0.000226
# 3070                              0.000156
#
#         Unemployment insurance compensation YR-1  \
# 0                                       0.000475
# 1                                       0.001896
# 2                                       0.000270
# 3                                       0.000166
# 4                                       0.000456
# ...                                          ...
# 3066                                    0.001887
# 3067                                    0.001251
# 3068                                    0.000815
# 3069                                    0.000353
# 3070                                    0.000216
#
#         Unemployment insurance compensation YR-2  \
# 0                                       0.000560
# 1                                       0.002171
# 2                                       0.000291
# 3                                       0.000194
# 4                                       0.000547
# ...                                          ...
# 3066                                    0.002248
# 3067                                    0.001533
# 3068                                    0.000951
# 3069                                    0.000427
# 3070                                    0.000271
#
#         Unemployment insurance compensation YR-3  \
# 0                                       0.000685
# 1                                       0.002721
# 2                                       0.000430
# 3                                       0.000273
# 4                                       0.000555
# ...                                          ...
# 3066                                    0.000732
# 3067                                    0.000351
# 3068                                    0.000244
# 3069                                    0.000085
# 3070                                    0.000059
#
#         Unemployment insurance compensation YR-4    Retirement and other YR-1  \
# 0                                       0.001166                     0.005368
# 1                                       0.005013                     0.025889
# 2                                       0.000556                     0.002768
# 3                                       0.000527                     0.002026
# 4                                       0.000933                     0.005137
# ...                                          ...                          ...
# 3066                                    0.001221                     0.003273
# 3067                                    0.001114                     0.001722
# 3068                                    0.000385                     0.001835
# 3069                                    0.000125                     0.000855
# 3070                                    0.000091                     0.000741
#
#         Retirement and other YR-2    Retirement and other YR-3  \
# 0                        0.005153                     0.005339
# 1                        0.024702                     0.024279
# 2                        0.002719                     0.002699
# 3                        0.001996                     0.002113
# 4                        0.005028                     0.005307
# ...                           ...                          ...
# 3066                     0.003192                     0.003235
# 3067                     0.001650                     0.001709
# 3068                     0.001774                     0.001775
# 3069                     0.000823                     0.000810
# 3070                     0.000715                     0.000715
#
#         Retirement and other YR-4   Dividends, interest, and rent 2/YR-1  \
# 0                        0.005191                               0.002892
# 1                        0.023489                               0.022516
# 2                        0.002673                               0.001001
# 3                        0.002120                               0.000569
# 4                        0.005221                               0.001910
# ...                           ...                                    ...
# 3066                     0.003226                               0.002569
# 3067                     0.001718                               0.054005
# 3068                     0.001704                               0.001175
# 3069                     0.000837                               0.000662
# 3070                     0.000733                               0.000478
#
#        Dividends, interest, and rent 2/YR-2  \
# 0                                  0.002921
# 1                                  0.022836
# 2                                  0.001027
# 3                                  0.000568
# 4                                  0.001983
# ...                                     ...
# 3066                               0.002522
# 3067                               0.052671
# 3068                               0.001157
# 3069                               0.000660
# 3070                               0.000479
#
#        Dividends, interest, and rent 2/YR-3  \
# 0                                  0.003160
# 1                                  0.022531
# 2                                  0.001066
# 3                                  0.000567
# 4                                  0.002263
# ...                                     ...
# 3066                               0.002379
# 3067                               0.046018
# 3068                               0.001082
# 3069                               0.000887
# 3070                               0.000484
#
#        Dividends, interest, and rent 2/YR-4  \
# 0                                  0.003139
# 1                                  0.020397
# 2                                  0.001088
# 3                                  0.000574
# 4                                  0.002212
# ...                                     ...
# 3066                               0.002341
# 3067                               0.041913
# 3068                               0.001049
# 3069                               0.000926
# 3070                               0.000530
#
#        Per capita personal income 4/YR-1   Per capita personal income 4/YR-2  \
# 0                               0.063715                            0.066662
# 1                               0.081360                            0.086424
# 2                               0.037890                            0.044446
# 3                               0.034097                            0.037272
# 4                               0.045695                            0.052118
# ...                                  ...                                 ...
# 3066                            0.088395                            0.092735
# 3067                            1.000000                            1.000000
# 3068                            0.055376                            0.058033
# 3069                            0.073544                            0.079164
# 3070                            0.066624                            0.069898
#
#        Per capita personal income 4/YR-3   Per capita personal income 4/YR-4  \
# 0                               0.076932                            0.082352
# 1                               0.098518                            0.103446
# 2                               0.051980                            0.053370
# 3                               0.041077                            0.045243
# 4                               0.058115                            0.055911
# ...                                  ...                                 ...
# 3066                            0.098108                            0.116768
# 3067                            1.000000                            1.000000
# 3068                            0.063306                            0.071767
# 3069                            0.105548                            0.117224
# 3070                            0.080994                            0.092517
#
#        Per capita net earnings 4/YR-1   Per capita net earnings 4/YR-2  \
# 0                            0.166299                         0.212539
# 1                            0.168381                         0.217814
# 2                            0.071024                         0.107268
# 3                            0.095528                         0.128035
# 4                            0.132220                         0.182567
# ...                               ...                              ...
# 3066                         0.234927                         0.305337
# 3067                         0.640996                         0.806552
# 3068                         0.134103                         0.174936
# 3069                         0.138388                         0.191073
# 3070                         0.136046                         0.180036
#
#        Per capita net earnings 4/YR-3   Per capita net earnings 4/YR-4  \
# 0                            0.191672                         0.231384
# 1                            0.199287                         0.236780
# 2                            0.099461                         0.121924
# 3                            0.112727                         0.140515
# 4                            0.156281                         0.173636
# ...                               ...                              ...
# 3066                         0.265844                         0.351838
# 3067                         0.750787                         0.732332
# 3068                         0.161367                         0.211379
# 3069                         0.191081                         0.224809
# 3070                         0.168860                         0.211054
#
#        Per capita personal current transfer receipts 4/YR-1  \
# 0                                              0.288745
# 1                                              0.337390
# 2                                              0.429459
# 3                                              0.314226
# 4                                              0.271133
# ...                                                 ...
# 3066                                           0.233518
# 3067                                           0.193882
# 3068                                           0.277641
# 3069                                           0.380557
# 3070                                           0.366732
#
#        Per capita personal current transfer receipts 4/YR-2  \
# 0                                              0.297256
# 1                                              0.342504
# 2                                              0.434705
# 3                                              0.324125
# 4                                              0.284864
# ...                                                 ...
# 3066                                           0.241739
# 3067                                           0.188457
# 3068                                           0.284031
# 3069                                           0.371608
# 3070                                           0.358989
#
#        Per capita personal current transfer receipts 4/YR-3  \
# 0                                              0.296138
# 1                                              0.338641
# 2                                              0.443614
# 3                                              0.328965
# 4                                              0.288135
# ...                                                 ...
# 3066                                           0.212314
# 3067                                           0.161685
# 3068                                           0.258125
# 3069                                           0.352360
# 3070                                           0.350768
#
#        Per capita personal current transfer receipts 4/YR-4  \
# 0                                              0.302371
# 1                                              0.360956
# 2                                              0.440485
# 3                                              0.356138
# 4                                              0.290969
# ...                                                 ...
# 3066                                           0.230762
# 3067                                           0.228710
# 3068                                           0.257717
# 3069                                           0.393206
# 3070                                           0.374314
#
#         Per capita income maintenance benefits 4/YR-1  \
# 0                                            0.140236
# 1                                            0.088889
# 2                                            0.287374
# 3                                            0.177104
# 4                                            0.124074
# ...                                               ...
# 3066                                         0.076263
# 3067                                         0.000000
# 3068                                         0.087879
# 3069                                         0.080640
# 3070                                         0.063636
#
#         Per capita income maintenance benefits 4/YR-2  \
# 0                                            0.210925
# 1                                            0.143918
# 2                                            0.337047
# 3                                            0.236305
# 4                                            0.192820
# ...                                               ...
# 3066                                         0.139276
# 3067                                         0.032962
# 3068                                         0.158465
# 3069                                         0.126586
# 3070                                         0.118694
#
#         Per capita income maintenance benefits 4/YR-3  \
# 0                                            0.188869
# 1                                            0.129261
# 2                                            0.350074
# 3                                            0.227071
# 4                                            0.170756
# ...                                               ...
# 3066                                         0.089247
# 3067                                         0.002964
# 3068                                         0.122674
# 3069                                         0.100774
# 3070                                         0.076898
#
#         Per capita income maintenance benefits 4/YR-4  \
# 0                                            0.181174
# 1                                            0.130455
# 2                                            0.339502
# 3                                            0.217958
# 4                                            0.149189
# ...                                               ...
# 3066                                         0.069454
# 3067                                         0.000000
# 3068                                         0.092758
# 3069                                         0.086132
# 3070                                         0.061001
#
#         Per capita unemployment insurance compensation 4/YR-1  \
# 0                                              0.002004
# 1                                              0.000000
# 2                                              0.014028
# 3                                              0.002004
# 4                                              0.002004
# ...                                                 ...
# 3066                                           0.138277
# 3067                                           0.168337
# 3068                                           0.116232
# 3069                                           0.142285
# 3070                                           0.092184
#
#         Per capita unemployment insurance compensation 4/YR-2  \
# 0                                              0.008499
# 1                                              0.005666
# 2                                              0.019830
# 3                                              0.005666
# 4                                              0.008499
# ...                                                 ...
# 3066                                           0.192635
# 3067                                           0.240793
# 3068                                           0.158640
# 3069                                           0.201133
# 3070                                           0.135977
#
#         Per capita unemployment insurance compensation 4/YR-3  \
# 0                                              0.050596
# 1                                              0.049272
# 2                                              0.081854
# 3                                              0.054305
# 4                                              0.039205
# ...                                                 ...
# 3066                                           0.081854
# 3067                                           0.068079
# 3068                                           0.052185
# 3069                                           0.049536
# 3070                                           0.037881
#
#         Per capita unemployment insurance compensation 4/YR-4  \
# 0                                              0.106315
# 1                                              0.118128
# 2                                              0.124262
# 3                                              0.134939
# 4                                              0.078146
# ...                                                 ...
# 3066                                           0.170831
# 3067                                           0.303044
# 3068                                           0.100409
# 3069                                           0.085189
# 3070                                           0.064289
#
#         Per capita retirement and other 4/YR-1  \
# 0                                     0.297339
# 1                                     0.365345
# 2                                     0.420402
# 3                                     0.317139
# 4                                     0.281382
# ...                                        ...
# 3066                                  0.247629
# 3067                                  0.220895
# 3068                                  0.295334
# 3069                                  0.413551
# 3070                                  0.403024
#
#         Per capita retirement and other 4/YR-2  \
# 0                                     0.289487
# 1                                     0.361981
# 2                                     0.414526
# 3                                     0.313755
# 4                                     0.280180
# ...                                        ...
# 3066                                  0.241974
# 3067                                  0.209244
# 3068                                  0.286681
# 3069                                  0.398094
# 3070                                  0.386516
#
#         Per capita retirement and other 4/YR-3  \
# 0                                     0.311620
# 1                                     0.379963
# 2                                     0.433647
# 3                                     0.338656
# 4                                     0.309485
# ...                                        ...
# 3066                                  0.235560
# 3067                                  0.203281
# 3068                                  0.285603
# 3069                                  0.404572
# 3070                                  0.411853
#
#         Per capita retirement and other 4/YR-4  \
# 0                                     0.286454
# 1                                     0.358818
# 2                                     0.396346
# 3                                     0.329934
# 4                                     0.287748
# ...                                        ...
# 3066                                  0.219370
# 3067                                  0.202754
# 3068                                  0.259382
# 3069                                  0.411357
# 3070                                  0.401315
#
#        Per capita dividends, interest, and rent 4/YR-1  \
# 0                                             0.014338
# 1                                             0.031955
# 2                                             0.011366
# 3                                             0.005042
# 4                                             0.007414
# ...                                                ...
# 3066                                          0.020598
# 3067                                          1.000000
# 3068                                          0.018319
# 3069                                          0.031502
# 3070                                          0.024837
#
#        Per capita dividends, interest, and rent 4/YR-2  \
# 0                                             0.015189
# 1                                             0.034561
# 2                                             0.012076
# 3                                             0.005110
# 4                                             0.008245
# ...                                                ...
# 3066                                          0.020600
# 3067                                          1.000000
# 3068                                          0.018472
# 3069                                          0.032218
# 3070                                          0.025390
#
#        Per capita dividends, interest, and rent 4/YR-3  \
# 0                                             0.018375
# 1                                             0.039355
# 2                                             0.013432
# 3                                             0.004103
# 4                                             0.010577
# ...                                                ...
# 3066                                          0.020386
# 3067                                          1.000000
# 3068                                          0.018088
# 3069                                          0.051164
# 3070                                          0.028976
#
#        Per capita dividends, interest, and rent 4/YR-4  \
# 0                                             0.019042
# 1                                             0.038238
# 2                                             0.013699
# 3                                             0.003749
# 4                                             0.010095
# ...                                                ...
# 3066                                          0.020315
# 3067                                          1.000000
# 3068                                          0.018086
# 3069                                          0.057812
# 3070                                          0.033552
#
#        Earnings by place of work YR-1   Earnings by place of work YR-2  \
# 0                            0.001689                         0.001601
# 1                            0.011590                         0.011191
# 2                            0.000937                         0.000989
# 3                            0.000670                         0.000646
# 4                            0.001324                         0.001434
# ...                               ...                              ...
# 3066                         0.004064                         0.003933
# 3067                         0.005590                         0.005227
# 3068                         0.001115                         0.001072
# 3069                         0.000485                         0.000480
# 3070                         0.000348                         0.000332
#
#        Earnings by place of work YR-3   Earnings by place of work YR-4  \
# 0                            0.001590                         0.001629
# 1                            0.010761                         0.010411
# 2                            0.000992                         0.001021
# 3                            0.000657                         0.000678
# 4                            0.001310                         0.001190
# ...                               ...                              ...
# 3066                         0.003832                         0.004174
# 3067                         0.005292                         0.004315
# 3068                         0.001084                         0.001123
# 3069                         0.000526                         0.000505
# 3070                         0.000331                         0.000349
#
#         Wages and salaries YR-1    Wages and salaries YR-2  \
# 0                      0.001657                   0.001563
# 1                      0.011263                   0.010794
# 2                      0.000900                   0.000914
# 3                      0.000679                   0.000663
# 4                      0.001096                   0.001091
# ...                         ...                        ...
# 3066                   0.003779                   0.003592
# 3067                   0.004806                   0.004577
# 3068                   0.001091                   0.001046
# 3069                   0.000453                   0.000449
# 3070                   0.000319                   0.000310
#
#         Wages and salaries YR-3    Wages and salaries YR-4  \
# 0                      0.001541                   0.001614
# 1                      0.010497                   0.010308
# 2                      0.000924                   0.001049
# 3                      0.000662                   0.000717
# 4                      0.001074                   0.001106
# ...                         ...                        ...
# 3066                   0.003510                   0.003918
# 3067                   0.004635                   0.003790
# 3068                   0.001042                   0.001125
# 3069                   0.000482                   0.000502
# 3070                   0.000299                   0.000341
#
#         Supplements to wages and salaries YR-1  \
# 0                                     0.001795
# 1                                     0.011231
# 2                                     0.001097
# 3                                     0.000762
# 4                                     0.001259
# ...                                        ...
# 3066                                  0.004430
# 3067                                  0.003850
# 3068                                  0.001418
# 3069                                  0.000595
# 3070                                  0.000485
#
#         Supplements to wages and salaries YR-2  \
# 0                                     0.001731
# 1                                     0.010802
# 2                                     0.001146
# 3                                     0.000767
# 4                                     0.001279
# ...                                        ...
# 3066                                  0.004259
# 3067                                  0.003707
# 3068                                  0.001407
# 3069                                  0.000613
# 3070                                  0.000480
#
#         Supplements to wages and salaries YR-3  \
# 0                                     0.001731
# 1                                     0.010686
# 2                                     0.001203
# 3                                     0.000786
# 4                                     0.001266
# ...                                        ...
# 3066                                  0.004216
# 3067                                  0.003685
# 3068                                  0.001414
# 3069                                  0.000639
# 3070                                  0.000469
#
#         Supplements to wages and salaries YR-4  \
# 0                                     0.001700
# 1                                     0.010022
# 2                                     0.001217
# 3                                     0.000790
# 4                                     0.001242
# ...                                        ...
# 3066                                  0.004372
# 3067                                  0.003179
# 3068                                  0.001427
# 3069                                  0.000637
# 3070                                  0.000501
#
#          Employer contributions for employee pension and insurance funds 5/YR-1  \
# 0                                              0.001809
# 1                                              0.010848
# 2                                              0.001131
# 3                                              0.000779
# 4                                              0.001291
# ...                                                 ...
# 3066                                           0.004251
# 3067                                           0.002988
# 3068                                           0.001383
# 3069                                           0.000579
# 3070                                           0.000517
#
#          Employer contributions for employee pension and insurance funds 5/YR-2  \
# 0                                              0.001742
# 1                                              0.010304
# 2                                              0.001181
# 3                                              0.000787
# 4                                              0.001306
# ...                                                 ...
# 3066                                           0.004051
# 3067                                           0.002928
# 3068                                           0.001389
# 3069                                           0.000600
# 3070                                           0.000508
#
#          Employer contributions for employee pension and insurance funds 5/YR-3  \
# 0                                              0.001739
# 1                                              0.010221
# 2                                              0.001222
# 3                                              0.000809
# 4                                              0.001284
# ...                                                 ...
# 3066                                           0.003947
# 3067                                           0.002881
# 3068                                           0.001374
# 3069                                           0.000611
# 3070                                           0.000489
#
#          Employer contributions for employee pension and insurance funds 5/YR-4  \
# 0                                              0.001680
# 1                                              0.009464
# 2                                              0.001216
# 3                                              0.000795
# 4                                              0.001244
# ...                                                 ...
# 3066                                           0.004081
# 3067                                           0.002467
# 3068                                           0.001355
# 3069                                           0.000593
# 3070                                           0.000515
#
#          Employer contributions for government social insurance YR-1  \
# 0                                              0.001766
# 1                                              0.012046
# 2                                              0.001025
# 3                                              0.000727
# 4                                              0.001193
# ...                                                 ...
# 3066                                           0.004810
# 3067                                           0.005682
# 3068                                           0.001494
# 3069                                           0.000629
# 3070                                           0.000418
#
#          Employer contributions for government social insurance YR-2  \
# 0                                              0.001709
# 1                                              0.011880
# 2                                              0.001073
# 3                                              0.000726
# 4                                              0.001221
# ...                                                 ...
# 3066                                           0.004712
# 3067                                           0.005392
# 3068                                           0.001447
# 3069                                           0.000642
# 3070                                           0.000422
#
#          Employer contributions for government social insurance YR-3  \
# 0                                              0.001713
# 1                                              0.011760
# 2                                              0.001160
# 3                                              0.000732
# 4                                              0.001226
# ...                                                 ...
# 3066                                           0.004836
# 3067                                           0.005543
# 3068                                           0.001505
# 3069                                           0.000704
# 3070                                           0.000425
#
#          Employer contributions for government social insurance YR-4  \
# 0                                              0.001750
# 1                                              0.011357
# 2                                              0.001220
# 3                                              0.000777
# 4                                              0.001240
# ...                                                 ...
# 3066                                           0.005070
# 3067                                           0.004883
# 3068                                           0.001600
# 3069                                           0.000743
# 3070                                           0.000469
#
#         Proprietors' income YR-1    Proprietors' income YR-2  \
# 0                       0.003685                    0.004781
# 1                       0.016016                    0.017382
# 2                       0.002893                    0.004377
# 3                       0.002427                    0.003485
# 4                       0.004766                    0.006991
# ...                          ...                         ...
# 3066                    0.007293                    0.008813
# 3067                    0.014699                    0.014625
# 3068                    0.002796                    0.003893
# 3069                    0.002480                    0.003616
# 3070                    0.002281                    0.003389
#
#         Proprietors' income YR-3    Proprietors' income YR-4  \
# 0                       0.002257                    0.003851
# 1                       0.012926                    0.013557
# 2                       0.001683                    0.002886
# 3                       0.001025                    0.002588
# 4                       0.003280                    0.003774
# ...                          ...                         ...
# 3066                    0.005760                    0.007433
# 3067                    0.011624                    0.010396
# 3068                    0.001473                    0.003001
# 3069                    0.001199                    0.002594
# 3070                    0.000898                    0.002446
#
#          Farm proprietors' income YR-1     Farm proprietors' income YR-2  \
# 0                             0.373560                          0.065940
# 1                             0.360585                          0.063322
# 2                             0.380558                          0.091331
# 3                             0.359317                          0.054851
# 4                             0.410104                          0.147478
# ...                                ...                               ...
# 3066                          0.376377                          0.071660
# 3067                          0.361513                          0.062052
# 3068                          0.363702                          0.059894
# 3069                          0.366469                          0.063970
# 3070                          0.358105                          0.056322
#
#          Farm proprietors' income YR-3     Farm proprietors' income YR-4  \
# 0                             0.052454                          0.060121
# 1                             0.058637                          0.062550
# 2                             0.065642                          0.056603
# 3                             0.043815                          0.051298
# 4                             0.087930                          0.052343
# ...                                ...                               ...
# 3066                          0.055255                          0.060723
# 3067                          0.043030                          0.051053
# 3068                          0.044020                          0.053091
# 3069                          0.045432                          0.053262
# 3070                          0.041290                          0.047814
#
#         Nonfarm proprietors' income YR-1    Nonfarm proprietors' income YR-2  \
# 0                                98667.0                             92960.0
# 1                               896813.0                            845313.0
# 2                                41926.0                             38528.0
# 3                                30962.0                             29159.0
# 4                               135374.0                            126804.0
# ...                                  ...                                 ...
# 3066                            326332.0                            325827.0
# 3067                            812014.0                            682892.0
# 3068                             50639.0                             47355.0
# 3069                             27993.0                             26018.0
# 3070
#
#         Nonfarm proprietors' income YR-3    Nonfarm proprietors' income YR-4  \
# 0                                96382.0                            100914.0
# 1                               758092.0                            742493.0
# 2                                44392.0                             41045.0
# 3                                29585.0                             27559.0
# 4                               117495.0                            105075.0
# ...                                  ...                                 ...
# 3066                            312728.0                            338051.0
# 3067                            695380.0                            546340.0
# 3068                             57440.0                             52866.0
# 3069                             38534.0                             25658.0
# 3070
#
#       Population YR-1  Population YR-2  Population YR-3  Population YR-4  \
# 0            0.006240         0.006140         0.006030         0.005889
# 1            0.026230         0.025359         0.024404         0.023333
# 2            0.002540         0.002537         0.002495         0.002492
# 3            0.002259         0.002257         0.002274         0.002214
# 4            0.006186         0.006119         0.006017         0.005908
# ...               ...              ...              ...              ...
# 3066         0.004264         0.004252         0.004238         0.004216
# 3067         0.002400         0.002392         0.002401         0.002333
# 3068         0.002142         0.002128         0.002103         0.002041
# 3069         0.000793         0.000790         0.000781         0.000760
# 3070         0.000700         0.000701         0.000682         0.000676
#
#        GeoFIPS
# 0      "01001"
# 1      "01003"
# 2      "01005"
# 3      "01007"
# 4      "01009"
# ...        ...
# 3066   "56037"
# 3067   "56039"
# 3068   "56041"
# 3069   "56043"
# 3070   "56045"
#
# [3071 rows x 97 columns]

# %%
import data_processing

results = read_data('2024_prediction_data.csv')

for result in results:
    state_abbrev = misc.us_state_to_abbrev[result["State"]]
    try:
        with open('CAINC1_Annual Personal Income by County/CAINC1_'+ state_abbrev + '_1969_2023.csv', 'r') as file:
            csv_reader = csv.DictReader(file)
            data = list(csv_reader)[:-5]
        for _ in data:
            del _["Region"]
            del _["TableName"]
            del _["Unit"]
            del _["LineCode"]
        
        
        econ_data = list(filter(lambda d: result["County"] in d["GeoName"], data))
        
        for ed in econ_data:
            if "Population" not in ed["Description"]:
                year = int(result["Year"])
                label = ed["Description"]
                result[label + "YR-1"] = int(ed[str(year - 1)]) 
                result[label + "YR-2"] = int(ed[str(year - 2)])
                result[label + "YR-3"] = int(ed[str(year - 3)])
                result[label + "YR-4"] = int(ed[str(year - 4)])
    except Exception as e:
        print(e)
        pass

df = pd.DataFrame(results)
# remove population columns
columns = df.columns
populations = [df[' Population (persons) 3/YR-1'],
            df[' Population (persons) 3/YR-2'],
            df[' Population (persons) 3/YR-3'], 
            df[' Population (persons) 3/YR-4']]
fips = df['GeoFIPS']
df.drop(columns = " Population (persons) 3/YR-1", inplace=True)
df.drop(columns = " Population (persons) 3/YR-2", inplace=True)
df.drop(columns = " Population (persons) 3/YR-3", inplace=True)
df.drop(columns = " Population (persons) 3/YR-4", inplace=True)
df.drop(columns = "GeoFIPS", inplace=True)

for column in df.columns:
    df.drop(df.loc[df[column] == ''].index, inplace=True)

#adjust for inflation
for i in df.index:
    try:
        year = int(df.iloc[i,1])
        df.iloc[i, 4:] = df.iloc[i, 4:].map(lambda x: int(x) * misc.cpi_dict[year])
    except Exception as e:
        pass

#add population columns back
df["Population YR-1"] = populations[0]
df["Population YR-2"] = populations[1]
df["Population YR-3"] = populations[2]
df["Population YR-4"] = populations[3]
df['GeoFIPS'] = fips

# NORMALIZE DATA
for column in df.columns[3:-1]:
    try:
        df[column] = df[column].map(lambda x: float(x))
        x_max = max(list(df[column]))
        x_min = min(list(df[column]))
        df[column] = df[column].map(lambda x: (x - x_min)/(x_max - x_min))
    except Exception as e:
        print(column, e)
        
        pass
df['Year'] = df['Year'].map(lambda x: str(x)[:-2])
filename = datetime.datetime.now().__str__()[:-7]
df.to_csv(filename)
# Out:
# 'utf-8' codec can't decode byte 0xf1 in position 2816: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 2816: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 2816: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 2816: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 2816: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 2816: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 2816: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 2816: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 2816: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 2816: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 2816: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 2816: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 2816: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 2816: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 2816: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 2816: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 2816: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 2816: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 2816: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 2816: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 2816: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 2816: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 2816: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 2816: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 2816: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 2816: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 2816: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 2816: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 2816: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 2816: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf1 in position 2816: invalid continuation byte
# invalid literal for int() with base 10: '(NA)'
# invalid literal for int() with base 10: '(NA)'
# Year float division by zero

# %%
data_training = read_data('training_data_extended.csv')
pd.DataFrame(data_training).columns[5:-1] == df.columns[4:-1]
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True])
